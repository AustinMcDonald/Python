# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
from scipy import optimize
import scipy
import scipy.ndimage as ndimage
import scipy.ndimage.filters as filters
from PIL import Image 
import numpy.polynomial.polynomial as poly
# %matplotlib inline

# %%
cd /Users/austinmcdonald/Desktop/test/Barium/Slide3/Spot1/
# Out:
# /Users/austinmcdonald/Desktop/test/Barium/Slide3/Spot1

# %%
files=os.listdir()

# %%
TestImage = np.array(Image.open(files[5]))

# %%
plt.imshow(TestImage, cmap='hot', interpolation='nearest')
plt.show()

# %%
Row = int(110) # define the area to take around the spots
Col = int(110) # define the area to take around the spots
Yindex = int(285)
Xindex = int(400)
Testspot = np.array(TestImage)[Yindex-Row:Yindex+Row+1,Xindex-Col:Xindex+Col+1]
plt.imshow(Testspot, cmap='hot', interpolation='nearest')
print(Testspot.shape)
plt.show()
# Out:
# (221, 221)

# %%
SavePath = '/Users/austinmcdonald/Desktop/test/cut'
WorkPath = '/Users/austinmcdonald/Desktop/test/Nothing/Slide1/'

# %%
cd /Users/austinmcdonald/Desktop/test/Nothing/Slide1/
# Out:
# /Users/austinmcdonald/Desktop/test/Nothing/Slide1

# %%
Folders=os.listdir()
Folders = [x for x in Folders if x != '.DS_Store']

# %%
xvs = np.arange(0,512)
Row = int(110) # define the area to take around the spots
Col = int(110) # define the area to take around the spots
Yindex = int(285)
Xindex = int(400)
for w in range(0,len(Folders)):
    folder = '/1Spot'+str(w)
    os.mkdir(SavePath+folder)
    files = os.listdir(Folders[int(w)])
    files = [x for x in files if x != '.DS_Store']
    for q in range(0,len(files)):
        spot = np.array(Image.open(WorkPath+'/'+Folders[int(w)]+'/'+files[q]))[Yindex-Row:Yindex+Row+1,Xindex-Col:Xindex+Col+1]
        im = Image.fromarray(spot.astype('float64'))
        im.save(SavePath+folder +'/'+ 'Cut' + files[q])

        Images = None

# %%
files
# Out:
# ['Spot1',
#  'Spot2',
#  'Spot3',
#  'Spot4',
#  'Spot5',
#  'Spot6',
#  'Spot7',
#  'Spot8',
#  'Spot9']

# %%
Slides = os.listdir()
Slides = [x for x in Slides if x != '.DS_Store']
Slides
# Out:
# ['Cut', 'Spot1', 'Spot2', 'Spot3', 'Spot4', 'Spot5', 'Spot6']

# %%
xvs = np.arange(0,512)
Row = int(110) # define the area to take around the spots
Col = int(110) # define the area to take around the spots
Yindex = int(285)
Xindex = int(400)
for q in range(0,len(Slides)):
    slide = WorkPath+'/'+Slides[q]
    Spots = os.listdir(slide)
    Spots = [x for x in Spots if x != '.DS_Store']
    for w in range(0,len(Spots)):
        dataPath = slide+'/'+Spots[w]
        files = os.listdir(dataPath)
        files = [x for x in files if x != '.DS_Store']
        CutFolder = '/Slide'+str(q)+'Spot'+str(w)
        os.mkdir(SavePath+CutFolder)
        for s in range(0,len(files)):

            spot = np.array(Image.open(dataPath+'/'+files[s]))[Yindex-Row:Yindex+Row+1,Xindex-Col:Xindex+Col+1]
            im = Image.fromarray(spot.astype('float64'))
            im.save(SavePath+CutFolder +'/' + files[s])

            Images = None

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
from scipy import optimize
import scipy
import scipy.ndimage as ndimage
import scipy.ndimage.filters as filters
from PIL import Image 
import numpy.polynomial.polynomial as poly
# %matplotlib inline

# %%
cd /Users/austinmcdonald/Desktop/test/Barium/Slide3/Spot4/
# Out:
# /Users/austinmcdonald/Desktop/test/Barium/Slide3/Spot4

# %%
files=os.listdir()

# %%
TestImage = np.array(Image.open(files[5]))

# %%
plt.imshow(TestImage, cmap='hot', interpolation='nearest')
plt.show()

# %%
Row = int(110) # define the area to take around the spots
Col = int(110) # define the area to take around the spots
Yindex = int(285)
Xindex = int(400)
Testspot = np.array(TestImage)[Yindex-Row:Yindex+Row+1,Xindex-Col:Xindex+Col+1]
plt.imshow(Testspot, cmap='hot', interpolation='nearest')
print(Testspot.shape)
plt.show()
# Out:
# (221, 221)

# %%
SavePath = '/Users/austinmcdonald/Desktop/test/cut'
WorkPath = '/Users/austinmcdonald/Desktop/test'

# %%
cd /Users/austinmcdonald/Desktop/test/Barium/
# Out:
# /Users/austinmcdonald/Desktop/test/Barium

# %%
DataSet=['Barium','Nothing']

# %%
xvs = np.arange(0,512)
Row = int(110) # define the area to take around the spots
Col = int(110) # define the area to take around the spots
Yindex = int(285)
Xindex = int(400)
for f in range(0,len(DataSet)):
    datas = WorkPath+'/'+DataSet[f]
    slides = os.listdir(datas)
    slides = [x for x in slides if x != '.DS_Store']
    for q in range(0,len(slides)):
        slide = datas+'/'+slides[q]
        Spots = os.listdir(slide)
        Spots = [x for x in Spots if x != '.DS_Store']
        for w in range(0,len(Spots)):
            dataPath = slide+'/'+Spots[w]
            files = os.listdir(dataPath)
            files = [x for x in files if x != '.DS_Store']
            CutFolder = '/Slide'+str(q)+'Spot'+str(w)
            os.mkdir(SavePath+'/'+ DataSet[f]+CutFolder)
            for s in range(0,len(files)):
                spot = np.array(Image.open(dataPath+'/'+files[s]))[Yindex-Row:Yindex+Row+1,Xindex-Col:Xindex+Col+1]
                im = Image.fromarray(spot.astype('float64'))
                im.save(SavePath+'/'+DataSet[f]+CutFolder +'/' + files[s])
                Images = None
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-18f84a7c2fa4> in <module>()
#      17             files = [x for x in files if x != '.DS_Store']
#      18             CutFolder = '/Slide'+str(q)+'Spot'+str(w)
# ---> 19             os.mkdir(SavePath+'/'+ DataSet[f]+CutFolder)
#      20             for s in range(0,len(files)):
#      21                 spot = np.array(Image.open(dataPath+'/'+files[s]))[Yindex-Row:Yindex+Row+1,Xindex-Col:Xindex+Col+1]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/austinmcdonald/Desktop/test/cut/Barium/Slide0Spot0'

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
from scipy import optimize
import scipy
import scipy.ndimage as ndimage
import scipy.ndimage.filters as filters
from PIL import Image 
import numpy.polynomial.polynomial as poly
# %matplotlib inline

# %%
#100x100
#x=450,y=220

# %%
cd /Users/austinmcdonald/Desktop/10-12-17/Ba/Slide1/Spot3
# Out:
# /Users/austinmcdonald/Desktop/10-12-17/Ba/Slide1/Spot3

# %%
TestImage = np.array(Image.open(files[5]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d245521b9867> in <module>()
# ----> 1 TestImage = np.array(Image.open(files[5]))
#
# NameError: name 'files' is not defined

# %%
plt.imshow(TestImage, cmap='hot', interpolation='nearest')
plt.show()

# %%
Row = int(110) # define the area to take around the spots
Col = int(110) # define the area to take around the spots
Yindex = int(288)
Xindex = int(322)
Testspot = np.array(TestImage)[Yindex-Row:Yindex+Row+1,Xindex-Col:Xindex+Col+1]
plt.imshow(Testspot, cmap='hot', interpolation='nearest')
plt.show()

# %%
cd /Users/austinmcdonald/Desktop/SingleMolecule-selected-092817/Images/Na
# Out:
# /Users/austinmcdonald/Desktop/SingleMolecule-selected-092817/Images/Na

# %%
SavePath = '/Users/austinmcdonald/Desktop/SingleMolecule-selected-092817/CutImages/NaSmall'

# %%
Folders = os.listdir()
#Folders = Folders[1:len(Folders)]
Folders
# Out:
# ['Slide1Spot1',
#  'Slide1Spot2',
#  'Slide1Spot3',
#  'Slide1Spot4',
#  'Slide1Spot5',
#  'Slide1Spot6']

# %%
xvs = np.arange(0,512)
Row = int(110) # define the area to take around the spots
Col = int(110) # define the area to take around the spots
Yindex = int(288)
Xindex = int(322)
for w in range(0,len(Folders)):
    folder = '/Sample'+str(w)
    os.mkdir(SavePath+folder)
    files = os.listdir(Folders[int(w)])
    for q in range(0,len(files)):
        
        spot = np.array(Image.open(Folders[int(w)]+'/'+files[q]))[Yindex-Row:Yindex+Row+1,Xindex-Col:Xindex+Col+1]
        im = Image.fromarray(spot.astype('float64'))
        im.save(SavePath+folder +'/'+ 'NaCut' + files[q])

        Images = None

# %%
SavePath+folder
# Out:
# '/Users/austinmcdonald/Desktop/SingleMolecule-selected-092817/CutImages/BaSmall/Sample7'

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'Slide1Spot3',
#  'Slide1Spot4',
#  'Slide1Spot5',
#  'Slide1Spot6',
#  'Slide2Spot1',
#  'Slide2Spot2',
#  'Slide2Spot4',
#  'Slide2Spot5']

# %%
spot.shape
# Out:
# (201, 201)

# %%
spot.dtype
# Out:
# dtype('uint16')

# %%
plt.imshow(Imdat, cmap='hot', interpolation='nearest')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8ccd8354f5ff> in <module>()
# ----> 1 plt.imshow(Imdat, cmap='hot', interpolation='nearest')
#       2 plt.show()
#
# NameError: name 'Imdat' is not defined

# %%
K=4
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N 
ma = running_mean(Imdat[250],K)
maxvs = running_mean(xvs,K)
len(ma)
# Out:
# 509

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter

# %matplotlib inline

# %%
cd /Users/austinmcdonald/Desktop/data/Fluo4/8-11-16/Ar fluo4-EDTA
# Out:
# /Users/austinmcdonald/Desktop/data/Fluo4/8-11-16/Ar Fluo4-EDTA

# %%
os.listdir()
# Out:
# ['CCD-Nooise.csv',
#  'EDTA-0.csv',
#  'EDTA-100.csv',
#  'EDTA-150.csv',
#  'EDTA-50.csv',
#  'water.csv']

# %%
backg = pd.read_csv('CCD-nooise.csv',delimiter=",",names = ['wave','back'],skiprows=33,skipfooter=1,engine='python')
bapta0 = pd.read_csv('EDTA-0.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
bapta50 = pd.read_csv('EDTA-50.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
bapta100 = pd.read_csv('EDTA-100.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
bapta150 = pd.read_csv('EDTA-150.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')

# %%
bapta0['dif'] = bapta0['sig'].diff().abs()
bapta0['BS'] = bapta0['sig']-backg['back']

bapta50['dif'] = bapta50['sig'].diff().abs()
bapta50['BS'] = bapta50['sig']-backg['back']

bapta100['dif'] = bapta100['sig'].diff().abs()
bapta100['BS'] = bapta100['sig']-backg['back']

bapta150['dif'] = bapta150['sig'].diff().abs()
bapta150['BS'] = bapta150['sig']-backg['back']

# %%
plt.figure(figsize=(10,10))

bapta0f = bapta0[bapta0['dif']<.05]
bapta150f = bapta150[bapta150['dif']<.1]
bapta50f = bapta50[bapta50['dif']<.1]
bapta100f = bapta100[bapta100['dif']<.1]



plt.plot(bapta0f['wave'],bapta0f['BS'],color='olivedrab',label=r'$0 \mu L$ $EDTA$')
plt.plot(bapta50f['wave'],bapta50f['BS'],color='coral',label=r'$50 \mu L$ $EDTA$')
plt.plot(bapta100f['wave'],bapta100f['BS'],color='darkkhaki',label=r'$100 \mu L$ $EDTA$')
plt.plot(bapta150f['wave'],bapta150f['BS'],color='steelblue',label=r'$150 \mu L$ $EDTA$')

#plt.text(600, .65, r'$\frac{F_{max}}{F_{min}} = 12.57$', fontsize=25)

plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Relitive Intensity', fontsize=32)
plt.title('Fluo-4 EDTA Concentrations', fontsize=32)
plt.legend(bbox_to_anchor=(1,1), loc=1, borderaxespad=0.,fontsize=22,shadow=True, fancybox=True)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)

plt.xlim(450,650)
plt.ylim(0,1)
#plt.savefig('Ar_Fluo4_EDTA.pdf')

plt.show()

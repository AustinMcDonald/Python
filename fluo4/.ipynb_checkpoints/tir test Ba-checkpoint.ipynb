# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter

# %matplotlib inline

# %%
cd /Users/austinmcdonald/Desktop/data/Fluo4/8-15-16/Ba_tirf_test
# Out:
# /Users/austinmcdonald/Desktop/data/Fluo4/8-15-16/Ba_tirf_test

# %%
os.listdir()
# Out:
# ['Ba-P205-40s.csv', 'NoBa-P205-40s.csv']

# %%
sig1 = pd.read_csv('Ba-P205-40s.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
sig0 = pd.read_csv('NoBa-P205-40s.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')

# %%
sig1['dif'] = sig1['sig'].diff().abs()

sig0['dif'] = sig0['sig'].diff().abs()

# %%
plt.figure(figsize=(10,10))

sig100f = sig100[sig100['dif']<.1]
sig50f = sig50[sig50['dif']<.05]
sig10f = sig10[sig10['dif']<.05]


plt.plot(sig100f['wave'],sig100f['BS'],color='steelblue',label=r'$100 \mu M$')
plt.plot(sig50f['wave'],sig50f['BS'],color='coral',label=r'$50 \mu M$')
plt.plot(sig10f['wave'],sig10f['BS'],color='olive',label=r'$10 \mu M$')

#plt.plot(backg['wave'],backg['sig'],color='darkkhaki',label='background')


plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Relitive Intensity', fontsize=32)
plt.title('Total Internal Reflection Fluorescein', fontsize=32)
plt.legend(bbox_to_anchor=(.6, .8), loc=2, borderaxespad=0.,fontsize=22,shadow=True, fancybox=True)

plt.xlim(450,650)

plt.show()

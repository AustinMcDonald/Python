# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit

# %matplotlib inline

# %%
cd /Users/austinmcdonald/Desktop/data/led sensitivity/first copy
# Out:
# /Users/austinmcdonald/Desktop/data/led sensitivity/first copy

# %%
#set path to the files location

path = '/Users/austinmcdonald/Desktop/data/led spec/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(np.genfromtxt(path + filenameled[x],delimiter=",",skip_header=33,skip_footer=1))
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][:,0])
    intensity.append(analysisled[y][:,1])

    
Meanwavelength = np.mean(wavelength,axis = 0)          # Finds the mean of the xvalues

Meanintensity = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr = Meanintensity + SDintensity                    # Adds the SD to the mean 
dnerr = Meanintensity - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
#plt.plot(Meanwavelength,Meanintensity)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
#plt.show()

# %%
#set path to the files location

#
#
#    BACKGROUND
#
#
path = '/Users/austinmcdonald/Desktop/data/led sensitivity/first copy/background/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append(analysisled[y][1])
    
Meanintensity0 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr0 = Meanintensity0 + SDintensity                    # Adds the SD to the mean 
dnerr0 = Meanintensity0 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
#plt.plot(Meanwavelength,Meanintensity0)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
#plt.show()

# %%
#set path to the files location

#
#
#    sig1-0.4
#
#
path = '/Users/austinmcdonald/Desktop/data/led sensitivity/first copy/sig1-0.4/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1] - Meanintensity0))
    
Meanintensity1 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr1 = Meanintensity1 + SDintensity                    # Adds the SD to the mean 
dnerr1 = Meanintensity1 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(Meanwavelength,Meanintensity1)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    sig2-0.4
#
#
path = '/Users/austinmcdonald/Desktop/data/led sensitivity/first copy/sig2-0.4/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1] - Meanintensity0))
    
Meanintensity2 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr2 = Meanintensity2 + SDintensity                    # Adds the SD to the mean 
dnerr2 = Meanintensity2 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(Meanwavelength,Meanintensity2)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    sig4-0.4
#
#
path = '/Users/austinmcdonald/Desktop/data/led sensitivity/first copy/sig4-0.4/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1] - Meanintensity0))
    
Meanintensity4 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr4 = Meanintensity4 + SDintensity                    # Adds the SD to the mean 
dnerr4 = Meanintensity4 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(Meanwavelength,Meanintensity4)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    sig8-0.4
#
#
path = '/Users/austinmcdonald/Desktop/data/led sensitivity/first copy/sig8-0.4/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1] - Meanintensity0))
    
Meanintensity8 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr8 = Meanintensity8 + SDintensity                    # Adds the SD to the mean 
dnerr8 = Meanintensity8 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(Meanwavelength,Meanintensity8)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(Meanwavelength,Meanintensity8/.4,label=r"$\frac{8\mu g}{cc}$",color='g')
plt.plot(Meanwavelength,Meanintensity4/.4,label=r"$\frac{4\mu g}{cc}$",color='m')
plt.plot(Meanwavelength,Meanintensity2/.4,label=r"$\frac{2\mu g}{cc}$",color='y')
plt.plot(Meanwavelength,Meanintensity1/.4,label=r"$\frac{1\mu g}{cc}$",color='c')
plt.plot(Meanwavelength,Meanintensity0/.4,label="bg",color='r')
plt.plot(Meanwavelength,Meanintensity/.015,label="led",color='b')
#plt.axvline(520, color='g', linestyle=':')
#plt.text(525,.95,'520nm',rotation=0,fontsize=15,color='g')
#plt.axvline(467, color='b', linestyle=':')
#plt.text(472,.8,'467nm',rotation=0,fontsize=15,color='b')
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)
#plt.legend(bbox_to_anchor=(.681, 1), loc=2, borderaxespad=0.,fontsize=32)

#plt.xlim([420,650])
#plt.ylim([-.02,1])

plt.suptitle('Fluorescein Excitation Spectrum',size= 32)
plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Relitive Intensity', fontsize=32)
#plt.savefig('Fluorescein Excitation Spectrum.pdf')
plt.show()

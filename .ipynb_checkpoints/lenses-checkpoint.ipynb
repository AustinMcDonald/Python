# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter

# %matplotlib inline

# %%
cd /Users/austinmcdonald/Desktop/data/lenses
# Out:
# /Users/austinmcdonald/Desktop/data/lenses

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '495glass.csv',
#  '570glass.csv',
#  'bothlenses.pdf',
#  'DMLP490.csv',
#  'DMLP490.xls',
#  'DMLP567.csv',
#  'DMLP567.xls',
#  'FELH0500.csv',
#  'FELH0500_Transmission (1).xlsx',
#  'FELH0550.csv',
#  'FELH0550_Transmission (1).xlsx',
#  'FESH0500.csv',
#  'FESH0500_Transmission.xlsx',
#  'FESH0550.csv',
#  'FESH0550_Transmission.xlsx',
#  'preimumfluolenses.pdf',
#  'preimumlenses.pdf',
#  'preimumrhodlenses.pdf']

# %%
g495 = pd.read_csv('495glass.csv',delimiter=",",names = ['wave','tra'],skiprows=2,skipfooter=1,engine='python')
g570 = pd.read_csv('570glass.csv',delimiter=",",names = ['wave','tra'],skiprows=2,skipfooter=1,engine='python')
m490 = pd.read_csv('DMLP490.csv',delimiter=",",names = ['wave','tra','wave2','ref'],skiprows=3,skipfooter=1,engine='python')
m567 = pd.read_csv('DMLP567.csv',delimiter=",",names = ['wave','tra','ref'],skiprows=2,skipfooter=1,engine='python')
felh0500 = pd.read_csv('FELH0500.csv',delimiter=",",names = ['wave','tra'],skiprows=2,skipfooter=1,engine='python')
felh0550 = pd.read_csv('FELH0550.csv',delimiter=",",names = ['wave','tra'],skiprows=2,skipfooter=1,engine='python')
fesh0500 = pd.read_csv('FESH0500.csv',delimiter=",",names = ['wave','tra'],skiprows=2,skipfooter=1,engine='python')
fesh0550 = pd.read_csv('FESH0550.csv',delimiter=",",names = ['wave','tra'],skiprows=2,skipfooter=1,engine='python')

# %%
#felh0500

# %%
plt.figure(figsize=(10,10))

plt.plot(m490['wave'],m490['tra'],label="transmission",color='k')
plt.plot(m490['wave2'],m490['ref'],label="reflection",color='r')

plt.axvline(495, color='k', linestyle='-')
plt.text(500,101,'495 glass filter',rotation=0,fontsize=15,color='k')
#plt.axvline(467, color='b', linestyle=':')
#plt.text(472,.8,'467nm',rotation=0,fontsize=15,color='b')

plt.legend(bbox_to_anchor=(.681, 1), loc=2, borderaxespad=0.,fontsize=32)

plt.xlim([400,700])
plt.ylim([-.10,110])

plt.suptitle('setup?',size= 32)
plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Percent transmitted', fontsize=32)
#plt.savefig('Fluo4 2.pdf')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(m567['wave'],m567['tra'],label="transmission",color='k')
plt.plot(m567['wave'],m567['ref'],label="reflection",color='r')

plt.axvline(570, color='k', linestyle='-')
plt.text(575,101,'570 glass filter',rotation=0,fontsize=15,color='k')
#plt.axvline(467, color='b', linestyle=':')
#plt.text(472,.8,'467nm',rotation=0,fontsize=15,color='b')

plt.legend(bbox_to_anchor=(.681, 1), loc=2, borderaxespad=0.,fontsize=32)

plt.xlim([500,750])
plt.ylim([-10,110])

plt.suptitle('Fluo4 in Imidazole buffer',size= 32)
plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Percent Reflection', fontsize=32)
#plt.savefig('Fluo4 2.pdf')
plt.show()

# %%
# Two subplots, unpack the axes array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.plot(m490['wave'],m490['tra'],label="transmission",color='b')
ax1.plot(m490['wave2'],m490['ref'],label="reflection",color='g')
ax1.set_xlim(400,700)
ax1.set_ylim(0,110)
ax1.axvline(495, color='k', linestyle='-')
ax1.text(500,101,'495 glass filter',rotation=0,fontsize=20,color='k')
ax1.tick_params(labelsize=20)
ax1.set_xlabel('Wavelength (nm)', fontsize=32)
ax1.set_ylabel('Percent Reflection', fontsize=32)
ax1.set_title('Fluo3/4 Optics', fontsize=32)
ax1.legend(bbox_to_anchor=(.6, .6), loc=2, borderaxespad=0.,fontsize=20,shadow=True, fancybox=True)

ax2.plot(m567['wave'],m567['tra'],label="transmission",color='b')
ax2.plot(m567['wave'],m567['ref'],label="reflection",color='g')
ax2.set_xlim(500,750)
ax2.set_ylim(0,110)
ax2.set_xlabel('Wavelength (nm)', fontsize=32)
ax2.axvline(570, color='k', linestyle='-')
ax2.text(575,101,'570 glass filter',rotation=0,fontsize=20,color='k')
ax2.set_title('Rhod2 Optics', fontsize=32)
ax2.tick_params(labelsize=20)
ax2.legend(bbox_to_anchor=(.6, .6), loc=2, borderaxespad=0.,fontsize=20,shadow=True, fancybox=True)

#plt.savefig('lenses.pdf')

# %%
plt.figure(figsize=(10,10))
plt.plot(m490['wave'],m490['tra'],label="transmission",color='b')
plt.plot(m490['wave2'],m490['ref'],label="reflection",color='g')
plt.xlim(400,700)
plt.ylim(0,110)
plt.axvline(495, color='k', linestyle='-')
plt.text(500,101,'495 glass filter',rotation=0,fontsize=20,color='k')
plt.tick_params(labelsize=20)
plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Percent Reflection', fontsize=32)
plt.title('Fluo3/4 Optics', fontsize=32)
plt.legend(bbox_to_anchor=(.6, .6), loc=2, borderaxespad=0.,fontsize=22,shadow=True, fancybox=True)
#plt.savefig('fluolenses.pdf')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(m567['wave'],m567['tra'],label="transmission",color='b')
plt.plot(m567['wave'],m567['ref'],label="reflection",color='g')
plt.xlim(500,750)
plt.ylim(0,110)
plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Percent Reflection', fontsize=32)

plt.axvline(570, color='k', linestyle='-')
plt.text(575,101,'570 glass filter',rotation=0,fontsize=22,color='k')
plt.title('Rhod2 Optics', fontsize=32)
plt.tick_params(labelsize=20)
plt.legend(bbox_to_anchor=(.6, .6), loc=2, borderaxespad=0.,fontsize=20,shadow=True, fancybox=True)
#plt.savefig('rhodlenses.pdf')

plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(m490['wave'],m490['tra'],label="transmission of DM",color='coral',linewidth=3,linestyle='-')
plt.plot(m490['wave2'],m490['ref'],label="reflection of DM",color='steelblue',linewidth=3,linestyle='--')
plt.plot(fesh0500['wave'],fesh0500['tra'],label='short pass filter',color='maroon',linewidth=4,linestyle=':')
plt.plot(felh0500['wave'],felh0500['tra'],label='long pass filter',color='olivedrab',linewidth=5,linestyle='-.')

plt.xlim(380,690)
plt.ylim(0,102)


plt.xlabel(r'Wavelength / nm', fontsize=28)
plt.ylabel('Reflection or Transmission', fontsize=28)
#plt.title('Fluo Optics', fontsize=32)
plt.legend(loc='center right',fontsize=26,shadow=True, fancybox=True)

plt.xticks(fontsize = 26)
plt.yticks(fontsize = 26)
plt.xticks([400,450,500,550,600,650],ha='left')
plt.tick_params(top="off",right='off')
plt.tick_params(axis='x', direction='out',width=2,length=5)
plt.tick_params(axis='y',width=2,length=5)

plt.tight_layout()
plt.savefig('/Users/austinmcdonald/Desktop/Plots/paper8-16/preimumfluolenses.pdf')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(m567['wave'],m567['tra'],label="transmission",color='steelblue',linewidth=2)
plt.plot(m567['wave'],m567['ref'],label="reflection",color='olivedrab',linewidth=2)
plt.plot(fesh0550['wave'],fesh0550['tra'],label='short pass',color='coral',linewidth=2)
plt.plot(felh0550['wave'],felh0550['tra'],label='long pass',color='darkkhaki',linewidth=2)
plt.xlim(370,750)
plt.ylim(0,110)
plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Percent Reflection', fontsize=32)

plt.title('Rhod Optics', fontsize=32)
plt.tick_params(labelsize=20)
plt.legend(bbox_to_anchor=(.6, .6), loc=2, borderaxespad=0.,fontsize=20,shadow=True, fancybox=True)
#plt.savefig('preimumrhodlenses.pdf')

plt.show()

# %%
plt.figure(figsize=(10,15))
plt.subplot(211)
plt.plot(m490['wave'],m490['tra'],label="transmission",color='steelblue',linewidth=2)
plt.plot(m490['wave2'],m490['ref'],label="reflection",color='olivedrab',linewidth=2)
plt.plot(fesh0500['wave'],fesh0500['tra'],label='short pass',color='coral',linewidth=2)
plt.plot(felh0500['wave'],felh0500['tra'],label='long pass',color='darkkhaki',linewidth=2)

plt.xlim(370,650)
plt.ylim(0,110)


plt.tick_params(labelsize=20)
#plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Percent Reflection', fontsize=32)
plt.title('Fluo Optics', fontsize=32)
plt.legend(bbox_to_anchor=(.6, .6), loc=2, borderaxespad=0.,fontsize=22,shadow=True, fancybox=True)

plt.subplot(212)

plt.plot(m567['wave'],m567['tra'],label="transmission",color='steelblue',linewidth=2)
plt.plot(m567['wave'],m567['ref'],label="reflection",color='olivedrab',linewidth=2)
plt.plot(fesh0550['wave'],fesh0550['tra'],label='short pass',color='coral',linewidth=2)
plt.plot(felh0550['wave'],felh0550['tra'],label='long pass',color='darkkhaki',linewidth=2)
plt.xlim(370,750)
plt.ylim(0,110)
plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Percent Reflection', fontsize=32)

plt.title('Rhod Optics', fontsize=32)
plt.tick_params(labelsize=20)
plt.legend(bbox_to_anchor=(.6, .6), loc=2, borderaxespad=0.,fontsize=20,shadow=True, fancybox=True)
#plt.savefig('preimumlenses.pdf')

plt.show()

# %%
plt.figure(figsize=(10,15))
plt.subplot(211)
plt.plot(m490['wave'],m490['tra'],label="transmission",color='b')
plt.plot(m490['wave2'],m490['ref'],label="reflection",color='g')
plt.plot(g495['wave'],g495['tra'],label="495nm glass filter",color='r')

plt.xlim(400,700)
plt.ylim(0,110)
plt.tick_params(labelsize=20)
plt.ylabel('Percent Reflection', fontsize=32)
plt.title('Fluo Optics', fontsize=32)
plt.legend(bbox_to_anchor=(.47, .6), loc=2, borderaxespad=0.,fontsize=22,shadow=True, fancybox=True)

plt.subplot(212)

plt.plot(m567['wave'],m567['tra'],label="transmission",color='b')
plt.plot(m567['wave'],m567['ref'],label="reflection",color='g')
plt.plot(g570['wave'],g570['tra'],label="570nm glass filter",color='r')

plt.xlim(400,700)
plt.ylim(0,110)
plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Percent Reflection', fontsize=32)

plt.title('Rhod Optics', fontsize=32)
plt.tick_params(labelsize=20)
plt.legend(bbox_to_anchor=(.05, .6), loc=2, borderaxespad=0.,fontsize=20,shadow=True, fancybox=True)
#plt.savefig('bothlenses.pdf')

plt.show()

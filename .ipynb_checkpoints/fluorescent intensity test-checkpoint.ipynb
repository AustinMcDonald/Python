# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit

# %matplotlib inline
# %alias_magic t timeit
# Out:
# Created `%t` as an alias for `%timeit`.
# Created `%%t` as an alias for `%%timeit`.

# %%
cd /Users/austinmcdonald/Desktop/data/led sensitivity/first copy
# Out:
# /Users/austinmcdonald/Desktop/data/led sensitivity/first copy

# %%
#set path to the files location

path = '/Users/austinmcdonald/Desktop/data/led spec/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(np.genfromtxt(path + filenameled[x],delimiter=",",skip_header=33,skip_footer=1))
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][:,0])
    intensity.append(analysisled[y][:,1])

    
Meanwavelength = np.mean(wavelength,axis = 0)          # Finds the mean of the xvalues

Meanintensity = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr = Meanintensity + SDintensity                    # Adds the SD to the mean 
dnerr = Meanintensity - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
#plt.plot(Meanwavelength,Meanintensity0)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
#plt.show()

# %%
#set path to the files location

#
#
#    BACKGROUND
#
#
path = '/Users/austinmcdonald/Desktop/data/led sensitivity/first copy/background/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append(analysisled[y][1])
    
Meanintensity0 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr0 = Meanintensity0 + SDintensity                    # Adds the SD to the mean 
dnerr0 = Meanintensity0 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(Meanwavelength,Meanintensity0)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    sig1-0.4
#
#
path = '/Users/austinmcdonald/Desktop/data/led sensitivity/first copy/sig1-0.4/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1] - Meanintensity0))
    
Meanintensity1 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr1 = Meanintensity1 + SDintensity                    # Adds the SD to the mean 
dnerr1 = Meanintensity1 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(Meanwavelength,Meanintensity1)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    BACKGROUND small
#
#
path = '/Users/austinmcdonald/Desktop/data/led sensitivity/second copy/background2/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append(analysisled[y][1])
    
Meanintensity00 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr00 = Meanintensity00 + SDintensity                    # Adds the SD to the mean 
dnerr00 = Meanintensity00 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(Meanwavelength,Meanintensity00)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    sig500-5.0
#
#
path = '/Users/austinmcdonald/Desktop/data/led sensitivity/second copy/sig500ng-5.0/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1] - Meanintensity00))
    
Meanintensity11 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr11 = Meanintensity11 + SDintensity                    # Adds the SD to the mean 
dnerr11 = Meanintensity11 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(Meanwavelength,Meanintensity11)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    sig125-5.0
#
#
path = '/Users/austinmcdonald/Desktop/data/led sensitivity/second copy/sig125ng-5.0/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1] - Meanintensity00))
    
Meanintensity22 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr22 = Meanintensity22 + SDintensity                    # Adds the SD to the mean 
dnerr22 = Meanintensity22 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(Meanwavelength,Meanintensity22)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    sig31.25-5.0
#
#
path = '/Users/austinmcdonald/Desktop/data/led sensitivity/second copy/sig31.25ng-5.0/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1] - Meanintensity00))
    
Meanintensity33 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr33 = Meanintensity33 + SDintensity                    # Adds the SD to the mean 
dnerr33 = Meanintensity33 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(Meanwavelength,Meanintensity33)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
plt.plot(Meanwavelength,Meanintensity11)
plt.plot(Meanwavelength,Meanintensity22)
plt.plot(Meanwavelength,Meanintensity33)
plt.show()

# %%
plt.plot(Meanwavelength,Meanintensity)
plt.plot(Meanwavelength,Meanintensity1/.4)
plt.plot(Meanwavelength,Meanintensity11/5)
plt.plot(Meanwavelength,Meanintensity22/5)
plt.plot(Meanwavelength,Meanintensity33/5)

plt.axvline(520, color='k', linestyle='--')
plt.axvline(495, color='r', linestyle='--')


plt.ylim([-.1,.15])
plt.show()

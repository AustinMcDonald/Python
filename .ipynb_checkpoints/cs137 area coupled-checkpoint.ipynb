# %%
import csv
import numpy as np
from numpy import diff
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import os
import glob
# %matplotlib inline
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
from scipy import asarray as ar,exp
import math
import pandas as pd 
from pandas import DataFrame, read_csv

# %%
cd /Users/austinmcdonald/Desktop/data/NaI test/CS137/little crystal/Cs-137_7-5/Coupled
# Out:
# /Users/austinmcdonald/Desktop/data/NaI test/CS137/little crystal/Cs-137_7-5/Coupled

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'Cs_137_Coupled_run1.jpg',
#  'F1Coupled_Area_Hist_800k_1kV00000.csv',
#  'F2Coupled_Pulse_Hist_800k_1kV00000.csv']

# %%
data = np.genfromtxt('F1Coupled_Area_Hist_800k_1kV00000.csv',delimiter=',',skip_header=1,skip_footer=315)
#BG = np.genfromtxt('F1Background_Run00000.csv',delimiter=',',skip_header=1,skip_footer=315)
data = np.flipud(dat[:,1])
#backg = np.flipud(BG[:,1])
len(data)
# Out:
# 4685

# %%
xvals = np.arange(1,len(data)+1)
#plt.xlim([2400,3700])
plt.plot(xvals,data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d4a657445a73> in <module>()
#       2 #plt.xlim([2400,3700])
#       3 plt.plot(xvals,data)
# ----> 4 plt.plot(xvals,backg)
#       5 plt.show()
#
# NameError: name 'backg' is not defined

# %%
data1 = data/9.2
backg1 = backg/50.76 
plt.xlim([0,1200])
plt.ylim([0,100])
plt.plot(xvals,data1)
plt.plot(xvals,backg1)
plt.plot(xvals,data1-backg1)
plt.show()

# %%
xcut = 3700
ycut = 4500

data0 = data[xcut:ycut]
xval0 = xvals[xcut:ycut]
plt.plot(xval0,data0)
plt.show()

# %%
x = xval0
y = data0

ypeak = max(y)
position = np.where(y == y.max())
pos = position[0][0]
xpeak = x[pos]


def gaus(x,a,x0,sigma):
    return a*exp(-(x-x0)**2/(2*sigma**2))

popt,pcov = curve_fit(gaus,x,y,p0=[ypeak,xpeak,1])

plt.plot(x,y,'k+:',label='data')
plt.plot(x,gaus(x,*popt),'r:',label='fit')
plt.legend()
plt.title('Fit for energy calabration')
plt.xlabel('Bins')
plt.ylabel('Counts')
print('Peak =',popt[1])
plt.show()
# Out:
# Peak = 980.654564178

# %%
print(1200-xpeak)
print(xpeak -182)
# Out:
# 182
# 836

# %%
Tarea = np.sum(data0)
Tarea
# Out:
# 58713.0

# %%
'''
len(data0)
'''
# Out:
# '\nlen(data0)\n'

# %%
le = len(data0)
BackBig = data0[0:50]
BackSmall = data0[le-50:le]
backB = np.sum(BackBig)/50
backS = np.sum(BackSmall)/50

# %%
Fracarea = np.cumsum(data0)
Farea = Fracarea/Tarea

# %%
background = (1-Farea)*backB + Farea*backS

# %%
test = data0 - background

# %%
plt.plot(xval0,data0)
plt.plot(xval0,background)
plt.plot(xval0,test)
plt.show()

# %%
x = xval0
y = test

ypeak = max(y)
position = np.where(y == y.max())
pos = position[0][0]
xpeak = x[pos]


def gaus(x,a,x0,sigma):
    return a*exp(-(x-x0)**2/(2*sigma**2))

popt,pcov = curve_fit(gaus,x,y,p0=[ypeak,xpeak,1])

fitted = popt

plt.plot(x,y,'k+:',label='data')
plt.plot(x,gaus(x,*fitted),'r',label='fit')
plt.legend()
plt.title('Fit for energy calabration')
plt.xlabel('Bins')
plt.ylabel('Counts')
print('Peak Position=',fitted[1])
plt.show()
# Out:
# Peak Position= 1022.09146075

# %%
ypeak = max(y)
position = np.where(y == y.max())
pos = position[0][0]
xpeak = x[pos]
pos
# Out:
# 204

# %%
right = y[pos:len(y)]
left = np.flipud(right)
halfP = np.append(left,[right])

dif = len(y)-len(halfP)
xvalP = x[dif:len(y)]

plt.plot(xvalP,halfP)
plt.show()

# %%
x = xvalP
y = halfP

ypeak = max(y)
position = np.where(y == y.max())
pos = position[0][0]
xpeak = x[pos]


def gaus(x,a,x0,sigma):
    return a*exp(-(x-x0)**2/(2*sigma**2))

popt,pcov = curve_fit(gaus,x,y,p0=[ypeak,xpeak,1])

plt.plot(x,y,'k+:',label='data')
plt.plot(x,gaus(x,*popt),'r',label='fit')
plt.legend()
plt.title('Fit for energy calabration')
plt.xlabel('Bins')
plt.ylabel('Counts')
print('Peak =',popt[0])
print('Peak Position=',popt[1])
print('sigma=',popt[2])
print('FWHM=',2.355*popt[2])
print('hash Resolution=',2.355*popt[2]/popt[0]*100)
print('Energy Resolution=',2.355*popt[2]/662*100)
plt.show()
# Out:
# Peak = 250.2551698
# Peak Position= 1040.5
# sigma= 32.2091447464
# FWHM= 75.8525358778
# hash Resolution= 30.3100774855
# Energy Resolution= 11.4580869906

# %%
# 661.64 = k * 1022
k= 661.64/fitted[1]

# %%
x = k*xval0
y = test

ypeak = max(y)
position = np.where(y == y.max())
pos = position[0][0]
xpeak = x[pos]


def gaus(x,a,x0,sigma):
    return a*exp(-(x-x0)**2/(2*sigma**2))

popt,pcov = curve_fit(gaus,x,y,p0=[ypeak,xpeak,1])

fitt = popt

plt.plot(x,y,'k+:',label='data')
plt.plot(x,gaus(x,*fitt),'r',label='fit')
plt.legend()
plt.title('Fit for energy calabration')
plt.xlabel('Energy KeV')
plt.ylabel('Counts')

print('Peak Height =',fitt[0])
print('Peak Position =',fitt[1])
print('sigma =',fitt[2])
print('FWHM =',2.355*fitt[2])
print('Energy Resolution =',2.355*fitt[2]/fitt[1]*100)
er = 2.355*fitt[2]/fitt[1]*100

plt.show()
# Out:
# Peak Height = 253.137896811
# Peak Position = 661.639933578
# sigma = 31.284670707
# FWHM = 73.675399515
# Energy Resolution = 11.1352709799

# %%
plt.figure(figsize=(10,10))

perc = ["%.2f" % er + '%']

plt.plot(k*xvals,data,label='data')
plt.ylim([0,1350])
plt.xlim([0,800])
#plt.plot(x,y,'k+:',label='data')
plt.plot(x,gaus(x,*fitt),'r',label='fit')
plt.plot(k*xval0,background,label='Background')
plt.legend(bbox_to_anchor=(.655, 1), loc=2, borderaxespad=0.,fontsize=20)
plt.axvline(470, color='k', linestyle=':')
plt.text(200,150,'Compton Edge 470KeV',rotation=0,fontsize=15,color='k')

plt.text(500,500,'Fitted Energy Resolution',rotation=0,fontsize=15,color='k')
plt.text(610,450,perc[0] ,rotation=0,fontsize=15,color='k')

plt.xlabel('Energy in KeV', fontsize= 18)
plt.ylabel('Counts', fontsize= 18)
plt.title('Cs137 Gamma Spectrum Area', fontsize= 18)



plt.savefig('Cs137 Spectrum1.pdf')
plt.show()

# %%
plt.figure(figsize=(10,10))

perc = ["%.2f" % er + '%']

plt.plot(k*xvals,data,label='data')
plt.xlim([420,800])
plt.ylim([0,400])
plt.plot(x,gaus(x,*fitt),'r',label='fit')
plt.plot(x,background,label='Background')
plt.legend(bbox_to_anchor=(.692, 1), loc=2, borderaxespad=0.,fontsize=17)

plt.axvline(470, color='k', linestyle=':')
plt.text(480,100,'Compton Edge 470KeV',rotation=0,fontsize=15,color='k')

plt.text(500,300,'Fitted Energy Resolution',rotation=0,fontsize=15,color='k')
plt.text(540,280,perc[0],rotation=0,fontsize=15,color='k')

plt.xlabel('Energy in KeV', fontsize= 18)
plt.ylabel('Counts', fontsize= 18)
plt.title('Cs137 Gamma Spectrum Area', fontsize= 18)



#plt.savefig('Cs137 Spectrum2.pdf')
plt.show()

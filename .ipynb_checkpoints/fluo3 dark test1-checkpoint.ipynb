# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter

# %matplotlib inline

# %%
#set path to the files location

path = '/Users/austinmcdonald/Desktop/fluorescin buffer test 2/LED-488-22ms.csv' # this is the path
#Nled=len(os.listdir(path))                            # this is the number of files
#filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
#for x in range(1,Nled):
analysisled = np.genfromtxt(path,delimiter=",",skip_header=33,skip_footer=1)
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
#for y in range(0,x):
wavelength1 = (analysisled[:,0])
intensity = (analysisled[:,1])

    
#Meanwavelength = np.mean(wavelength,axis = 0)          # Finds the mean of the xvalues

#Meanintensity = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr = Meanintensity + SDintensity                    # Adds the SD to the mean 
#dnerr = Meanintensity - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,intensity)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


plt.suptitle('LED Spectrum',size= 18)
plt.xlabel('Wavelength', fontsize=18)
plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    500-500 water 40 seconds
#     
#
path = '/Users/austinmcdonald/Desktop/fluo3 new/w500-bf500-ba0-w100/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity0 = np.mean(intensity,axis = 0)             # Finds the mean of the yvalues
#Meanintensity0 = savgol_filter(np.mean(intensity,axis = 0), 95, 3) 

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity1 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity1 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity0)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    500-500 water 40 seconds
#     
#
path = '/Users/austinmcdonald/Desktop/fluo3 new/w500-bf500-ba100-w0/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity1 = np.mean(intensity,axis = 0)             # Finds the mean of the yvalues
#Meanintensity1 = savgol_filter(np.mean(intensity,axis = 0), 95, 3) 

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity1 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity1 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity1)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
mary = Meanintensity1-Meanintensity0
plt.plot(wavelength1,mary)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#set path to the files location

#
#
#    1000-0 water 40 seconds
#     
#
path = '/Users/austinmcdonald/Desktop/fluo3 new/w1000-bf0-ba0-w100/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity0 = np.mean(intensity,axis = 0)             # Finds the mean of the yvalues
#Meanintensity2 = savgol_filter(np.mean(intensity,axis = 0), 95, 3) 

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity1 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity1 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity2)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    500-500 water 40 seconds
#     
#
path = '/Users/austinmcdonald/Desktop/fluo3 new/w1000-bf0-ba100-w0/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity3 = np.mean(intensity,axis = 0)             # Finds the mean of the yvalues
#Meanintensity3 = savgol_filter(np.mean(intensity,axis = 0), 95, 3) 

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity1 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity1 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity3)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
mary1 = Meanintensity3-Meanintensity2
plt.plot(wavelength1,mary1)
plt.show()

# %%
#set path to the files location

#
#
#     water 40 seconds
#     
#
path = '/Users/austinmcdonald/Desktop/fluo3 new/without/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity8 = np.mean(intensity,axis = 0)             # Finds the mean of the yvalues
#Meanintensity8 = savgol_filter(np.mean(intensity,axis = 0), 95, 3) 

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity1 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity1 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity8)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#      40 seconds
#     
#
path = '/Users/austinmcdonald/Desktop/fluo3 new/with/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity9 = np.mean(intensity,axis = 0)             # Finds the mean of the yvalues
#Meanintensity9 = savgol_filter(np.mean(intensity,axis = 0), 95, 3) 

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity1 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity1 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity9)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
plt.plot(wavelength1,Meanintensity8)
plt.plot(wavelength1,Meanintensity9)
plt.xlim([495,600])
plt.show()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit

# %matplotlib inline

# %%
cd /Users/austinmcdonald/Desktop/data/LED Data/rhodB
# Out:
# /Users/austinmcdonald/Desktop/data/LED Data/rhodB

# %%
#set path to the files location

path = '/Users/austinmcdonald/Desktop/data/LED Data/rhodB/LED/greenled-7ms.csv' # this is the path

led = np.genfromtxt(path ,delimiter=",",skip_header=33,skip_footer=1)

ledwavelength = led[:,0]
ledintensity = led[:,1]

plt.figure(figsize=(6,6))
plt.plot(ledwavelength,ledintensity)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    BACKGROUND
#
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/rhodB/1stConcentrations/background/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append(analysisled[y][1])
    
Meanint0 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

#plt.figure(figsize=(6,6))
plt.plot(ledwavelength,Meanint0)

#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location
#
#    40 micro molar 2.3 seconds
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/rhodB/1stConcentrations/40microM/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
#    intensity.append((analysisled[y][1] - Meanint0))
    intensity.append((analysisled[y][1] ))
    
Meanint40 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues


#plt.figure(figsize=(6,6))
plt.plot(ledwavelength,Meanint40)
plt.plot(ledwavelength,ledintensity)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location
#
#    10 micro molar 2.3 seconds
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/rhodB/1stConcentrations/10microM/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
#    intensity.append((analysisled[y][1] - Meanint0))
    intensity.append((analysisled[y][1] ))
    
Meanint10 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues


#plt.figure(figsize=(6,6))
plt.plot(ledwavelength,Meanint10)
plt.plot(ledwavelength,ledintensity)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location
#
#    0.62 micro molar 2.3 seconds
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/rhodB/1stConcentrations/0.62microM/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
#    intensity.append((analysisled[y][1] - Meanint0))
    intensity.append((analysisled[y][1] ))
    
Meanint062 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues


#plt.figure(figsize=(6,6))
plt.plot(ledwavelength,Meanint062)
plt.plot(ledwavelength,ledintensity)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location
#
#    0.04 micro molar 2.3 seconds
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/rhodB/1stConcentrations/0.04microM/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
#    intensity.append((analysisled[y][1] - Meanint0))
    intensity.append((analysisled[y][1] ))
    
Meanint004 = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues


#plt.figure(figsize=(6,6))
plt.plot(ledwavelength,Meanint004)
plt.plot(ledwavelength,ledintensity)
#plt.plot(ledwavelength,Meanint0)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(ledwavelength,Meanint40,label=r"$40\mu M$",color='g')
plt.plot(ledwavelength,Meanint10,label=r"$10\mu M$",color='m')
plt.plot(ledwavelength,Meanint062,label=r"$0.62\mu M$",color='y')
plt.plot(ledwavelength,Meanint004,label=r"$0.04\mu M$",color='c')
#plt.plot(ledwavelength,Meanint0,label="bg",color='r')
plt.plot(ledwavelength,ledintensity,label="led",color='b')
plt.axvline(588, color='g', linestyle=':')
#plt.text(525,.95,'520nm',rotation=0,fontsize=15,color='g')
#plt.axvline(467, color='b', linestyle=':')
#plt.text(472,.8,'467nm',rotation=0,fontsize=15,color='b')
plt.legend(bbox_to_anchor=(.76, 1), loc=2, borderaxespad=0.,fontsize=18)

plt.xlim([480,700])
#plt.ylim([-.02,1])

plt.suptitle('RhodB Excitation Spectrum',size= 22)
plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Relitive Intensity', fontsize=32)
#plt.savefig('Fluorescein Excitation Spectrum.pdf')
plt.show()

# %%
import os
import glob
import math
import matplotlib.pyplot as plt
import csv 
import pandas as pd
import numpy as np
# %matplotlib inline
from pandas import DataFrame, read_csv
from scipy.optimize import curve_fit
from scipy import asarray as ar,exp
import scipy.special as sse
from scipy.stats import chisquare
from scipy.signal import savgol_filter

# %%
cd /Users/austinmcdonald/Desktop/data/NaI test/CS137/Areas
# Out:
# /Users/austinmcdonald/Desktop/data/NaI test/CS137/Areas

# %%
allFiles = glob.glob("*.csv")
df = pd.concat((pd.read_csv(f,header=None) for f in allFiles), axis=1)
rows = len(df[0])
columns = len(allFiles)
new_length = rows*columns
areas = df.values.reshape(new_length,1)

# %%
#Plotting Raw Data

#nbins= 50
nbins= 1000

hist, bin_edges = np.histogram(areas , nbins)
bin_centres = (bin_edges[:-1] + bin_edges[1:])/2

plt.figure(figsize=(10,10))
plt.plot(bin_centres,hist,color='k')
#plt.hist(areas, bins=nbins)
#areahist = np.histogram(areas, nbins) 
#yaxis = areahist[0]
#xaxis = areahist[1]
plt.xlim(3e-7,2e-6)
plt.show()

# %%
# given a simple attinauation I=I0*e^(-mu*x)
#this assumes linear att which is not the case but is okay for this
#the values for 500keV are mu = 1.64 for Pb and 0.73 for Cu

atthistPb = hist*np.exp(-1.64*3.5)
atthistCu = hist*np.exp(-0.73*3.5)
plt.figure(figsize=(10,10))
plt.plot(bin_centres,hist,color='k',label='Cs137')
plt.plot(bin_centres,atthistPb,color='b',label='3.5cm lead att')
plt.plot(bin_centres,atthistCu,color='r',label='3.5cm copper att')
plt.xlim(3e-7,2e-6)
#plt.ylim(0,500)
plt.legend()
plt.show()

# %%
xcut = 250
ycut = 420

sm = savgol_filter(hist, 21, 3)
histtest = hist[xcut:ycut]
binctest = bin_centres[xcut:ycut]
smt = sm[xcut:ycut]
plt.plot(binctest,histtest,'o',markersize=2)
plt.plot(binctest,smt)

# %%
def find_nearest(array,value):
    idx = (np.abs(array-value)).argmin()
    return array[idx]
maxx = ycut-xcut

mtes = max(smt)
half = mtes/2
whr = np.where(smt==mtes)[0][0]
thebin = binctest[whr]
L = histtest[0:whr]
R = histtest[whr:maxx]
LP =find_nearest(L,half)
RP =find_nearest(R,half)
whereL = np.where(L==LP)[0][0]
whereR = np.where(R==RP)[0][0]
Lpoint = binctest[whereL]
Rpoint = binctest[whr+whereR]
fwhm = Rpoint-Lpoint
res = (fwhm/thebin) *100
print('FWHM =',fwhm)
print('Resolution =',res)
# Out:
# FWHM = 9.3069636e-08
# Resolution = 7.52739380725

# %%
#Background Subtraction

LLS = []
LLS.append(np.log(np.log(np.sqrt(hist+1)+1)+1))   #LLS operator

m=21   #no. of iterations
w = np.zeros(len(LLS[0]))

for p in range(1,m):           #SNIP Algorithm
    for i in range(1,len(LLS[0])-p):
        a1 = LLS[0][i]
        a2 = (LLS[0][i-p]+LLS[0][i+p])/2
        w[i] = min(a1,a2)
    LLS[0] = w

bg = ((np.exp(np.exp(w)-1)-1)**2)-1    #Inverse LLS 

nobg = hist - bg

plt.plot(bin_centres,nobg)
plt.plot(bin_centres,hist)
plt.show()

plt.plot(bin_centres,bg)
plt.plot(bin_centres,hist)
plt.xlim(1e-6,1.5e-6)
plt.show()

# %%
xcut2 = 250
ycut2 = 400

sm2 = savgol_filter(nobg, 21, 3)
histtest2 = nobg[xcut2:ycut2]
binctest = bin_centres[xcut2:ycut2]
smt2 = sm2[xcut2:ycut2]
plt.plot(binctest,histtest2,'o',markersize=2)
plt.plot(binctest,smt2)

# %%
maxx2 = ycut-xcut

mtes2 = max(smt2)
half2 = mtes2/2
whr2 = np.where(smt2==mtes2)[0][0]
thebin2 = binctest[whr2]
L2 = histtest2[0:whr2]
R2 = histtest2[whr2:maxx2]
LP2 =find_nearest(L2,half2)
RP2 =find_nearest(R2,half2)
whereL2 = np.where(L2==LP2)[0][0]
whereR2 = np.where(R2==RP2)[0][0]
Lpoint2 = binctest[whereL2]
Rpoint2 = binctest[whr2+whereR2]
fwhm2 = Rpoint2-Lpoint2
res2 = (fwhm2/thebin2) *100
print('fwhm2 =',fwhm2)
print('res2 =',res2)
# Out:
# fwhm2 = 8.7429052e-08
# res2 = 7.07118812197

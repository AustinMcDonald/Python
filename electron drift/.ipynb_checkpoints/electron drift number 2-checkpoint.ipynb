# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
from scipy import integrate

# %matplotlib inline

# %%
cd /Users/austinmcdonald/Desktop/data/electron drift
# Out:
# /Users/austinmcdonald/Desktop/data/electron drift

# %%
alldata = None
alldata = []
for files in glob.glob("*.csv"):
    alldata.append(files)
#alldata

# %%
tst
# Out:
#                         1             2        3      time       voltage
# 0           Record Length  2.500020e+05   Points -0.000012 -6.796670e-04
# 1         Sample Interval  2.000000e-09        s -0.000012 -1.999020e-04
# 2           Trigger Point  6.000000e+03  Samples -0.000012 -2.398820e-04
# 3            Trigger Time  8.496200e-01        s -0.000012 -5.597250e-04
# 4                     NaN           NaN      NaN -0.000012 -4.397840e-04
# 5       Horizontal Offset -1.200170e-05        s -0.000012  3.252610e-19
# 6                     NaN           NaN      NaN -0.000012 -3.598240e-04
# 7                     NaN           NaN      NaN -0.000012 -7.196470e-04
# 8                     NaN           NaN      NaN -0.000012 -2.398820e-04
# 9                     NaN           NaN      NaN -0.000012  3.198430e-04
# 10                    NaN           NaN      NaN -0.000012 -2.398820e-04
# 11                    NaN           NaN      NaN -0.000012 -3.198430e-04
# 12                    NaN           NaN      NaN -0.000012 -2.798630e-04
# 13                    NaN           NaN      NaN -0.000012 -3.198430e-04
# 14                    NaN           NaN      NaN -0.000012 -1.599220e-04
# 15                    NaN           NaN      NaN -0.000012 -4.797650e-04
# 16                    NaN           NaN      NaN -0.000012 -5.197450e-04
# 17                    NaN           NaN      NaN -0.000012 -3.598240e-04
# 18                    NaN           NaN      NaN -0.000012 -5.597250e-04
# 19                    NaN           NaN      NaN -0.000012 -2.398820e-04
# 20                    NaN           NaN      NaN -0.000012  1.599220e-04
# 21                    NaN           NaN      NaN -0.000012 -7.996080e-05
# 22                    NaN           NaN      NaN -0.000012 -3.598240e-04
# 23                    NaN           NaN      NaN -0.000012 -3.998040e-04
# 24                    NaN           NaN      NaN -0.000012 -5.197450e-04
# 25                    NaN           NaN      NaN -0.000012 -3.198430e-04
# 26                    NaN           NaN      NaN -0.000012 -4.397840e-04
# 27                    NaN           NaN      NaN -0.000012 -7.596270e-04
# 28                    NaN           NaN      NaN -0.000012 -4.797650e-04
# 29                    NaN           NaN      NaN -0.000012 -7.996080e-05
# ...                   ...           ...      ...       ...           ...
# 249972                NaN           NaN      NaN  0.000488 -3.998040e-04
# 249973                NaN           NaN      NaN  0.000488 -9.195490e-04
# 249974                NaN           NaN      NaN  0.000488 -5.197450e-04
# 249975                NaN           NaN      NaN  0.000488 -1.279370e-03
# 249976                NaN           NaN      NaN  0.000488 -5.597250e-04
# 249977                NaN           NaN      NaN  0.000488 -1.239390e-03
# 249978                NaN           NaN      NaN  0.000488 -6.396860e-04
# 249979                NaN           NaN      NaN  0.000488 -7.996080e-04
# 249980                NaN           NaN      NaN  0.000488 -7.996080e-04
# 249981                NaN           NaN      NaN  0.000488 -8.395880e-04
# 249982                NaN           NaN      NaN  0.000488 -8.795690e-04
# 249983                NaN           NaN      NaN  0.000488 -1.079470e-03
# 249984                NaN           NaN      NaN  0.000488 -1.119450e-03
# 249985                NaN           NaN      NaN  0.000488 -9.995100e-04
# 249986                NaN           NaN      NaN  0.000488 -7.196470e-04
# 249987                NaN           NaN      NaN  0.000488 -9.595290e-04
# 249988                NaN           NaN      NaN  0.000488 -7.996080e-04
# 249989                NaN           NaN      NaN  0.000488 -4.397840e-04
# 249990                NaN           NaN      NaN  0.000488  3.998040e-05
# 249991                NaN           NaN      NaN  0.000488 -7.596270e-04
# 249992                NaN           NaN      NaN  0.000488 -5.997060e-04
# 249993                NaN           NaN      NaN  0.000488 -6.796670e-04
# 249994                NaN           NaN      NaN  0.000488 -1.999020e-04
# 249995                NaN           NaN      NaN  0.000488 -1.999020e-04
# 249996                NaN           NaN      NaN  0.000488 -5.997060e-04
# 249997                NaN           NaN      NaN  0.000488 -1.239390e-03
# 249998                NaN           NaN      NaN  0.000488 -7.996080e-04
# 249999                NaN           NaN      NaN  0.000488 -5.997060e-04
# 250000                NaN           NaN      NaN  0.000488 -1.399310e-03
# 250001                NaN           NaN      NaN  0.000488 -8.395880e-04
#
# [250002 rows x 5 columns]

# %%
plt.plot(adata[0]['time'],adata[0]['voltage'])
plt.xlim(1e-5,5e-4)
plt.ylim(-.02,.02)
# Out:
# (-0.02, 0.02)

# %%
data = dict()
area= dict()
area1hold = dict()
area2hold = dict()

adata = dict()
intensity = dict()
leng = len(alldata)
for x in range(0,leng):
    data[x] = pd.read_csv(alldata[x],delimiter=",",names = ['1','2','3','time','voltage'],skiprows=0,skipfooter=0,engine='python')
   
    adata[x] = data[x][(data[x]['time']>5e-5) ]

    area[x] = integrate.trapz(adata[x]['voltage'], adata[x]['time'])


    #data[x]['dif'] = data[x]['sig'].diff().abs()
    #data[x]['BS'] = (data[x]['sig']-backg['sig'])
    #dataf[x] = data[x][data[x]['dif']<.02]
    #datacut[x] = dataf[x][(dataf[x]['wave']>490) & (dataf[x]['wave']<700)]

# %%
areas = []
for x in range(0,leng):
    areas.append(area[x])
areas=np.array(areas)
meanarea  = float(sum(areas))/len(areas)   
SDarea  = np.std(areas)
print('Mean Area =',meanarea)
print('SD =',SDarea)
# Out:
# Mean Area = -1.1639244419707315e-06
# SD = 1.74474478547e-07

# %%
meanarea  = float(sum(areas))/len(areas)   
SDarea  = np.std(areas)
# Out:
# array([ -1.06104746e-06,  -8.45309532e-07,  -8.23159981e-07,
#         -1.02074493e-06,  -1.01224003e-06,  -1.23659320e-06,
#         -1.03184697e-06,  -1.19871975e-06,  -9.71752902e-07,
#         -9.89686648e-07,  -1.14969079e-06,  -1.05946847e-06,
#         -9.77230093e-07,  -1.04922887e-06,  -9.83713053e-07,
#         -1.14164345e-06,  -1.02304145e-06,  -1.17746282e-06,
#         -1.02881341e-06,  -1.14702104e-06,  -1.12522725e-06,
#         -1.05093900e-06,  -1.02138081e-06,  -3.78197755e-07,
#         -8.38806105e-07,  -8.37588199e-07,  -1.24964371e-06,
#         -1.02486696e-06,  -1.25694369e-06,  -1.25154154e-06,
#         -1.25736484e-06,  -1.29304669e-06,  -1.05527328e-06,
#         -9.65586959e-07,  -9.76578168e-07,  -1.02392611e-06,
#         -1.07409237e-06,  -1.07140746e-06,  -1.10339119e-06,
#         -1.11094995e-06,  -1.16315206e-06,  -1.30641426e-06,
#         -1.24196728e-06,  -1.09865784e-06,  -1.17360433e-06,
#         -1.40353133e-06,  -1.27373343e-06,  -1.26434316e-06,
#         -1.29237601e-06,  -1.10561640e-06,  -1.13820066e-06,
#         -1.24795351e-06,  -1.12185661e-06,  -1.23842874e-06,
#         -1.31455055e-06,  -1.21934501e-06,  -1.15657161e-06,
#         -1.26597168e-06,  -1.30154181e-06,  -1.49370241e-06,
#         -1.39600643e-06,  -1.12436314e-06,  -1.29285989e-06,
#         -1.19452235e-06,  -1.11993628e-06,  -1.16822982e-06,
#         -8.67229865e-07,  -1.41658485e-06,  -1.25499252e-06,
#         -1.29730763e-06,  -1.21255645e-06,  -1.42013028e-06,
#         -1.37599531e-06,  -1.42800870e-06,  -1.29912643e-06,
#         -1.04197463e-06,  -1.12368303e-06,  -1.24313028e-06,
#         -1.34838593e-06,  -9.60925222e-07,  -1.34661972e-06,
#         -1.30608576e-06,  -1.39316718e-06,  -1.29557701e-06,
#         -1.07868755e-06,  -1.36208375e-06,  -1.40537421e-06,
#         -1.29034796e-06,  -1.37126319e-06,  -1.42054476e-06,
#         -1.06897966e-06,  -1.34507728e-06,  -1.32140583e-06,
#         -8.54555771e-07,  -1.29624218e-06,  -1.22063646e-06,
#         -1.34151291e-06,  -9.97636098e-07,  -1.21008785e-06])

# %%
plt.hist(areas,11, color='r')

plt.show()

# %%
plt.figure(figsize=(7,7))

plt.plot(dataf[0]['Time']*1e6,dataf[0]['CH1']*1e3,label= 'CH1',linewidth=2)
plt.plot(dataf[0]['Time']*1e6,dataf[0]['CH2']*1e3,label= 'CH2',linewidth=2)

plt.xlabel(r'Time / $\mu$ s', fontsize=28)
plt.ylabel('Voltage / m V', fontsize=28)
#plt.title('Fluo-4 Calicum Induced Fluorescence', fontsize=32)
plt.legend(loc='center right',fontsize=26,shadow=True, fancybox=True)
#plt.xticks(fontsize = 26)
#plt.yticks(fontsize = 26)
#plt.xticks([450,475,500,525,550,575,600,625],ha='left')
#plt.tick_params(top="off",right='off')
#plt.tick_params(axis='x', direction='out',width=2,length=5)
##plt.tick_params(axis='y',width=2,length=5)

plt.tight_layout()
plt.xlim(-200,800)
#plt.ylim(0,1.02)
#plt.savefig('/Users/austinmcdonald/Desktop/Plots/paper8-16/Ar_Fluo4_ca_IF.pdf')
plt.show()

# %%
plt.figure(figsize=(10,7))

plt.plot(dataf[70]['Time']*1e6,dataf[70]['sig']*1e3,label= 'sig',linewidth=2)

plt.xlabel(r'Time / $\mu$ s', fontsize=28)
plt.ylabel('Voltage / m V', fontsize=28)
#plt.title('Fluo-4 Calicum Induced Fluorescence', fontsize=32)
plt.legend(loc='upper right',fontsize=26,shadow=True, fancybox=True)
#plt.xticks(fontsize = 26)
#plt.yticks(fontsize = 26)
#plt.xticks([450,475,500,525,550,575,600,625],ha='left')
#plt.tick_params(top="off",right='off')
#plt.tick_params(axis='x', direction='out',width=2,length=5)
##plt.tick_params(axis='y',width=2,length=5)

plt.tight_layout()
plt.xlim(-200,800)
#plt.ylim(0,1.02)
#plt.savefig('/Users/austinmcdonald/Desktop/Plots/paper8-16/Ar_Fluo4_ca_IF.pdf')
plt.show()

# %%
plt.figure(1)
plt.figure(figsize=(8,8))

# linear
plt.subplot(221)
plt.plot(dataf[0]['Time']*1e6,dataf[0]['CH1']*1e3,label= 'CH1',linewidth=2)
plt.plot(dataf[0]['Time']*1e6,dataf[0]['CH2']*1e3,label= 'CH2',linewidth=2)
plt.subplot(222)
plt.plot(dataf[10]['Time']*1e6,dataf[10]['CH1']*1e3,label= 'CH1',linewidth=2)
plt.plot(dataf[10]['Time']*1e6,dataf[10]['CH2']*1e3,label= 'CH2',linewidth=2)
plt.subplot(223)
plt.plot(dataf[20]['Time']*1e6,dataf[20]['CH1']*1e3,label= 'CH1',linewidth=2)
plt.plot(dataf[20]['Time']*1e6,dataf[20]['CH2']*1e3,label= 'CH2',linewidth=2)
plt.subplot(224)
plt.plot(dataf[30]['Time']*1e6,dataf[30]['CH1']*1e3,label= 'CH1',linewidth=2)
plt.plot(dataf[30]['Time']*1e6,dataf[30]['CH2']*1e3,label= 'CH2',linewidth=2)


#plt.savefig('/Users/austinmcdonald/Desktop/Plots/paper8-16/Ar_Fluo4_ca_IF.pdf')
plt.show()

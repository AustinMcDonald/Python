# %%
import os
import glob
import math
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib.cm as cm

import csv 
import pandas as pd
import numpy as np
# %matplotlib inline
from pandas import DataFrame, read_csv
from scipy.optimize import curve_fit
from scipy import asarray as ar,exp
import scipy.special as sse
from scipy.stats import chisquare

# %%
cd /Users/austinmcdonald/Desktop/Xenon/RGA-Edrift/
# Out:
# /Users/austinmcdonald/Desktop/Xenon/RGA-Edrift

# %%
files = glob.glob("*.txt")
files.sort()
files  = files[0::2]
files
# Out:
# ['Xe-000.txt',
#  'Xe-003.txt',
#  'Xe-035-S.txt',
#  'Xe-035.txt',
#  'Xe-050.txt',
#  'Xe-065.txt',
#  'Xe-085.txt',
#  'Xe-095.txt',
#  'Xe-099.txt',
#  'Xe-100.txt']

# %%
Norm = [1.09e-5,1.09e-5,2.4e-5,1.9e-5,1.4e-5,1.3e-5,1.2e-5,1.2e-5,1.33e-5,1.28e-5]

# %%
name    = []
Percent = []
DataX   = dict()
DataY   = dict()
for x in range(0,len(files)):
    nameH = files[x].split(".")[0]
    name.append(nameH)
    PerH = int(nameH.split("-")[1])
    Percent.append(PerH)
    DAT =  np.genfromtxt(files[x],delimiter=',',skip_header=20)
    DataX[x] = DAT[:,0]
    DataY[x] = DAT[:,1]

# %%
Percent
# Out:
# [0, 3, 35, 35, 50, 65, 85, 95, 99, 100]

# %%
plt.figure(figsize=(15,9))
#for x in range(0,len(files)):
for x in range(2,4):

    plt.semilogy(DataX[x],DataY[x]/Norm[x],label=name[x])
    
plt.xlabel('Mass / amu',fontsize=26)

plt.ylabel('mBar',fontsize=26)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.xticks(np.arange(0, 140, 20))
plt.xlim(10,140)
#plt.ylim(1e-9,3e-5)
plt.grid()
plt.legend(loc='upper right',fontsize=10)
plt.tight_layout()


plt.show()

# %%
for x in range(2,4):

    a,b =AREA_FINDER(DataX[x],DataY[x]/Norm[x])
    print(a/b)
# Out:
# 19.4902321283
# 37.2325908625

# %%
def AREA_FINDER(X,Y):
    Ar1 = np.where(X==19.5)[0][0]
    Ar2 = np.where(X==20.5)[0][0]
    Ar3 = np.where(X==36)[0][0]
    Ar4 = np.where(X==37)[0][0]
    Ar5 = np.where(X==40)[0][0]
    Ar6 = np.where(X==41)[0][0]
    Xe1 = np.where(X==64)[0][0]
    Xe2 = np.where(X==74)[0][0]
    Xe3 = np.where(X==128)[0][0]
    Xe4 = np.where(X==140)[0][0] 
    
    
    argon1 = np.sum(Y[Ar1:Ar2])
    argon2 = np.sum(Y[Ar3:Ar4])
    argon3 = np.sum(Y[Ar5:Ar6])
    Xenon1 = np.sum(Y[Xe1:Xe2])
    Xenon2 = np.sum(Y[Xe3:Xe4])
    A = argon1+argon2+argon3
    B = Xenon1+Xenon2
    return A,B

# %%
plt.figure(figsize=(9,9))
for x in range(0,len(files)):
    a,b =AREA_FINDER(DataX[x],DataY[x]/Norm[x])
    plt.scatter(Percent[x],a/b)

# %%
name = files[0].split(".")[0]
Percent = int(name.split("-")[1])

# %%
Percent
# Out:
# 0

# %%
Xe100 = np.genfromtxt('/Users/austinmcdonald/Desktop/Xenon/RGA-Edrift/xenon-100/P-11_128.txt',delimiter=',',skip_header=20)
Xe100B = np.genfromtxt('/Users/austinmcdonald/Desktop/Xenon/RGA-Edrift/xenon-100/P-11_B.txt',delimiter=',',skip_header=20)
Xe099 = np.genfromtxt('/Users/austinmcdonald/Desktop/Xenon/RGA-Edrift/xenon-099/P-09.txt',delimiter=',',skip_header=20)
Xe095 = np.genfromtxt('/Users/austinmcdonald/Desktop/Xenon/RGA-Edrift/xenon-095/P-10.txt',delimiter=',',skip_header=20)
Xe085 = np.genfromtxt('/Users/austinmcdonald/Desktop/Xenon/RGA-Edrift/xenon-085/P-11.txt',delimiter=',',skip_header=20)
Xe065 = np.genfromtxt('/Users/austinmcdonald/Desktop/Xenon/RGA-Edrift/xenon-065/P-11.txt',delimiter=',',skip_header=20)
Xe050 = np.genfromtxt('/Users/austinmcdonald/Desktop/Xenon/RGA-Edrift/xenon-050/P-11.txt',delimiter=',',skip_header=20)
Xe035 = np.genfromtxt('/Users/austinmcdonald/Desktop/Xenon/RGA-Edrift/xenon-035/P-11.txt',delimiter=',',skip_header=20)
Xe003 = np.genfromtxt('/Users/austinmcdonald/Desktop/Xenon/RGA-Edrift/xenon-003/P-11.txt',delimiter=',',skip_header=20)
Xe000 = np.genfromtxt('/Users/austinmcdonald/Desktop/Xenon/RGA-Edrift/xenon-000/P-11.txt',delimiter=',',skip_header=20)
#Xe085 = np.genfromtxt('ArXe.txt',delimiter=',',skip_header=20)

# %%
plt.figure(figsize=(15,9))
plt.semilogy(Xe100[:,0],Xe100[:,1],label='100')
plt.semilogy(Xe100B[:,0],Xe100B[:,1],label='100')
#plt.ylim(1,10)

# %%
plt.figure(figsize=(15,9))
'''plt.semilogy(Xe100[:,0],Xe100[:,1],label='100')
#plt.semilogy(Xe099[:,0],Xe099[:,1],label='99')
#plt.semilogy(Xe095[:,0],Xe095[:,1],label='95')
#plt.semilogy(Xe085[:,0],Xe085[:,1],label='85')
plt.semilogy(Xe065[:,0],Xe065[:,1],label='65')
plt.semilogy(Xe050[:,0],Xe050[:,1],label='50')
plt.semilogy(Xe035[:,0],Xe035[:,1],label='35')
plt.semilogy(Xe003[:,0],Xe003[:,1],label='3')
plt.semilogy(Xe000[:,0],Xe000[:,1],label='0')
'''

plt.semilogy(Xe100[:,0],Xe100[:,1]/1.28e-5,label='100')
#plt.semilogy(Xe099[:,0],Xe099[:,1]/1.33e-5,label='99')
#plt.semilogy(Xe095[:,0],Xe095[:,1]/1.2e-5,label='95')
#plt.semilogy(Xe085[:,0],Xe085[:,1]/1.2e-5,label='85')
plt.semilogy(Xe065[:,0],Xe065[:,1]/1.3e-5,label='65')
plt.semilogy(Xe050[:,0],Xe050[:,1]/1.4e-5,label='50')
plt.semilogy(Xe035[:,0],Xe035[:,1]/1.9e-5,label='35')
plt.semilogy(Xe003[:,0],Xe003[:,1]/1.09e-5,label='3')
plt.semilogy(Xe000[:,0],Xe000[:,1]/1.09e-5,label='0')


#plt.semilogy(ArXeB[:,0],ArXeB[:,1])

#plt.semilogy(amu2,torr2,color='steelblue',linewidth=2,label='Day2-Baking')
plt.xlabel('Mass / amu',fontsize=26)

plt.ylabel('Torr',fontsize=26)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.xticks(np.arange(0, 140, 20))
#plt.ylim(1e-4,1)
#plt.xlim(0,60)
#plt.xlim(120,140)
#plt.xlim(60,90)

#plt.ylim(1e-9,3e-5)
plt.grid()
plt.legend(loc='upper left',fontsize=20)
plt.tight_layout()
#plt.savefig('Rga-fill-4-25.pdf')
'''#### Argon areas
plt.axvline(19,color='m',linewidth=2)
plt.axvline(21,color='m',linewidth=2)

plt.axvline(35.5,color='k',linewidth=2)
plt.axvline(37.5,color='k',linewidth=2)

plt.axvline(41.5,color='r',linewidth=2)
plt.axvline(39.5,color='r',linewidth=2)

### Xenon area
plt.axvline(64,color='k',linewidth=2)
plt.axvline(74,color='k',linewidth=2)

plt.axvline(128,color='r',linewidth=2)
plt.axvline(140,color='r',linewidth=2)
'''
plt.show()

# %%
Xe1 = np.where(Xe003[:,0]==80)[0][0]
Xe2 = np.where(Xe003[:,0]==90)[0][0]
Xe3 = np.where(Xe003[:,0]==100)[0][0]
Xe4 = np.where(Xe003[:,0]==112)[0][0]
Xenon1 = np.sum(Xe003[:,1][Xe1:Xe2])
Xenon2 = np.sum(Xe003[:,1][Xe3:Xe4])
XeB = Xenon1+Xenon2
XeB
# Out:
# 4.5931e-07

# %%
def AREA_FINDER(X,Y):
    Ar1 = np.where(X==19.5)[0][0]
    Ar2 = np.where(X==20.5)[0][0]
    Ar3 = np.where(X==36)[0][0]
    Ar4 = np.where(X==37)[0][0]
    Ar5 = np.where(X==40)[0][0]
    Ar6 = np.where(X==41)[0][0]
    Xe1 = np.where(X==64)[0][0]
    Xe2 = np.where(X==74)[0][0]
    Xe3 = np.where(X==128)[0][0]
    Xe4 = np.where(X==140)[0][0] 
    
    
    argon1 = np.sum(Y[Ar1:Ar2])
    argon2 = np.sum(Y[Ar3:Ar4])
    argon3 = np.sum(Y[Ar5:Ar6])
    Xenon1 = np.sum(Y[Xe1:Xe2])
    Xenon2 = np.sum(Y[Xe3:Xe4])
    A = argon1+argon2+argon3
    B = Xenon1+Xenon2
    return A,B

'''
plt.axvline(19.5,color='m',linewidth=2)
plt.axvline(20.5,color='m',linewidth=2)

plt.axvline(36,color='k',linewidth=2)
plt.axvline(37,color='k',linewidth=2)

plt.axvline(41,color='r',linewidth=2)
plt.axvline(40,color='r',linewidth=2)'''
# Out:
# "\nplt.axvline(19.5,color='m',linewidth=2)\nplt.axvline(20.5,color='m',linewidth=2)\n\nplt.axvline(36,color='k',linewidth=2)\nplt.axvline(37,color='k',linewidth=2)\n\nplt.axvline(41,color='r',linewidth=2)\nplt.axvline(40,color='r',linewidth=2)"

# %%
a,b =AREA_FINDER(Xe100[:,0],Xe100[:,1]/1.33e-5)
a
# Out:
# 0.052134586466165422

# %%
a,b =AREA_FINDER(Xe000[:,0],Xe000[:,1]/1.09e-5)
a
# Out:
# 12.733550458715598

# %%
a,b =AREA_FINDER(Xe003[:,0],Xe003[:,1]/1.09e-5)
a
# Out:
# 14.503449541284404

# %%
a,b =AREA_FINDER(Xe035[:,0],Xe035[:,1])
a/b
# Out:
# 37.232590862471959

# %%
plt.semilogy(Xe100[:,0],Xe100[:,1],label='100')
#plt.semilogy(Xe099[:,0],Xe099[:,1],label='99')
#plt.semilogy(Xe095[:,0],Xe095[:,1],label='95')
#plt.semilogy(Xe085[:,0],Xe085[:,1],label='85')
plt.semilogy(Xe065[:,0],Xe065[:,1],label='65')
plt.semilogy(Xe050[:,0],Xe050[:,1],label='50')
plt.semilogy(Xe035[:,0],Xe035[:,1],label='35')
plt.semilogy(Xe003[:,0],Xe003[:,1],label='3')
plt.semilogy(Xe000[:,0],Xe000[:,1],label='0')

# %%
plt.semilogy(Xe100[:,0],Xe100[:,1]/1.28e-5,label='100')
#plt.semilogy(Xe099[:,0],Xe099[:,1]/1.33e-5,label='99')
#plt.semilogy(Xe095[:,0],Xe095[:,1]/1.2e-5,label='95')
#plt.semilogy(Xe085[:,0],Xe085[:,1]/1.2e-5,label='85')
plt.semilogy(Xe065[:,0],Xe065[:,1]/1.3e-5,label='65')
plt.semilogy(Xe050[:,0],Xe050[:,1]/1.4e-5,label='50')
plt.semilogy(Xe035[:,0],Xe035[:,1]/1.9e-5,label='35')
plt.semilogy(Xe003[:,0],Xe003[:,1]/1.09e-5,label='3')
plt.semilogy(Xe000[:,0],Xe000[:,1]/1.09e-5,label='0')

# %%
Conc = [100,99,95,85,65,50,35,3,0]
plt.figure(figsize=(9,9))

a,b =AREA_FINDER(Xe100[:,0],Xe100[:,1]/1.28e-5)
plt.scatter(100,a/b)
a,b =AREA_FINDER(Xe050[:,0],Xe050[:,1]/1.4e-5)
plt.scatter(50,a/b)
a,b =AREA_FINDER(Xe003[:,0],Xe003[:,1]/1.09e-5)
plt.scatter(3,a/b)

a,b =AREA_FINDER(Xe035[:,0],Xe035[:,1]/1.9e-5)
plt.scatter(35,a/b)
a,b =AREA_FINDER(Xe050[:,0],Xe050[:,1]/1.4e-5)
plt.scatter(50,a/b)
a,b =AREA_FINDER(Xe065[:,0],Xe065[:,1]/1.3e-5)
plt.scatter(65,a/b)

a,b =AREA_FINDER(Xe085[:,0],Xe085[:,1]/1.2e-5)
plt.scatter(85,a/b)
a,b =AREA_FINDER(Xe095[:,0],Xe095[:,1]/1.2e-5)
plt.scatter(95,a/b)
a,b =AREA_FINDER(Xe099[:,0],Xe099[:,1]/1.33e-5)
plt.scatter(99,a/b)

a,b =AREA_FINDER(Xe000[:,0],Xe000[:,1]/1.09e-5)
Bb = XeB/1.09e-5
plt.scatter(0,a/Bb)

# %%
Conc = [100,99,95,85,65,50,35,3,0]
plt.figure(figsize=(9,9))

a,b =AREA_FINDER(Xe100[:,0],Xe100[:,1]/1.33e-5)
plt.scatter(a,b)
a,b =AREA_FINDER(Xe050[:,0],Xe050[:,1]/1.4e-5)
plt.scatter(a,b)
a,b =AREA_FINDER(Xe003[:,0],Xe003[:,1]/1.09e-5)
plt.scatter(a,b)

a,b =AREA_FINDER(Xe035[:,0],Xe035[:,1]/1.9e-5)
plt.scatter(a,b)
a,b =AREA_FINDER(Xe050[:,0],Xe050[:,1]/1.4e-5)
plt.scatter(a,b)
a,b =AREA_FINDER(Xe065[:,0],Xe065[:,1]/1.3e-5)
plt.scatter(a,b)

a,b =AREA_FINDER(Xe085[:,0],Xe085[:,1]/1.2e-5)
plt.scatter(a,b)
a,b =AREA_FINDER(Xe095[:,0],Xe095[:,1]/1.2e-5)
plt.scatter(a,b)
a,b =AREA_FINDER(Xe099[:,0],Xe099[:,1]/1.2e-5)
plt.scatter(a,b)

a,b =AREA_FINDER(Xe000[:,0],Xe000[:,1]/1.09e-5)
Bb = XeB/1.09e-5
plt.scatter(a,Bb)

# %%
a/Bb
# Out:
# 317.18403692495264

# %%
a,b =AREA_FINDER(Xe100[:,0],Xe100[:,1]/1.33e-5)
a/b
# Out:
# 0.11985314580153598

# %%
ArXe100 = np.genfromtxt('ArXe.txt',delimiter=',',skip_header=20)
ArXeB = np.genfromtxt('RGABack.txt',delimiter=',',skip_header=20)

XeArCon = np.genfromtxt('XeArCon.txt',delimiter=',',skip_header=20)
XeArConB = np.genfromtxt('RGABackCON.txt',delimiter=',',skip_header=20)

# %%
plt.figure(figsize=(15,9))
plt.semilogy(Xe000[:,0],Xe000[:,1])

#plt.semilogy(amu2,torr2,color='steelblue',linewidth=2,label='Day2-Baking')
plt.xlabel('Mass / amu',fontsize=26)

plt.ylabel('Torr',fontsize=26)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.xticks(np.arange(0, 140, 20))
#plt.xlim(0,60)
plt.ylim(1e-9,3e-5)
plt.grid()
plt.legend(loc='upper left',fontsize=20)
plt.tight_layout()
#plt.savefig('Rga-fill-4-25.pdf')
#### Argon areas
plt.axvline(19.5,color='m',linewidth=2)
plt.axvline(20.5,color='m',linewidth=2)

plt.axvline(36,color='k',linewidth=2)
plt.axvline(37,color='k',linewidth=2)

plt.axvline(41,color='r',linewidth=2)
plt.axvline(40,color='r',linewidth=2)

### Xenon area
plt.axvline(64,color='k',linewidth=2)
plt.axvline(74,color='k',linewidth=2)

plt.axvline(128,color='r',linewidth=2)
plt.axvline(140,color='r',linewidth=2)

plt.show()
# Out:
# //anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
Ar1 = np.where(ArXe[:,0]==19)[0][0]
Ar2 = np.where(ArXe[:,0]==21)[0][0]
Ar3 = np.where(ArXe[:,0]==35.5)[0][0]
Ar4 = np.where(ArXe[:,0]==37.5)[0][0]
Ar5 = np.where(ArXe[:,0]==39.5)[0][0]
Ar6 = np.where(ArXe[:,0]==41.5)[0][0]
Xe1 = np.where(ArXe[:,0]==64)[0][0]
Xe2 = np.where(ArXe[:,0]==74)[0][0]
Xe3 = np.where(ArXe[:,0]==128)[0][0]
Xe4 = np.where(ArXe[:,0]==140)[0][0]

# %%
argon1 = np.sum(ArXe[:,1][Ar1:Ar2])
argon2 = np.sum(ArXe[:,1][Ar3:Ar4])
argon3 = np.sum(ArXe[:,1][Ar5:Ar6])
Xenon1 = np.sum(ArXe[:,1][Xe1:Xe2])
Xenon2 = np.sum(ArXe[:,1][Xe3:Xe4])

print("Argon Xenon3%")
print("Argon area ", argon1+argon2+argon3)
print()
print("Xenon area ", Xenon1+Xenon2)
# Out:
# Argon Xenon3%
# Argon area  0.00013552942
#
# Xenon area  8.9704e-07

# %%
plt.figure(figsize=(15,9))
plt.semilogy(XeArCon[:,0],XeArCon[:,1])
plt.semilogy(XeArConB[:,0],XeArConB[:,1])

#plt.semilogy(amu2,torr2,color='steelblue',linewidth=2,label='Day2-Baking')
plt.xlabel('Mass / amu',fontsize=26)

plt.ylabel('Torr',fontsize=26)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.xticks(np.arange(0, 140, 20))
#plt.xlim(0,60)
plt.ylim(1e-9,3e-5)
plt.grid()
plt.legend(loc='upper left',fontsize=20)
plt.tight_layout()
#plt.savefig('Rga-fill-4-25.pdf')
#### Argon areas
plt.axvline(19,color='m',linewidth=2)
plt.axvline(21,color='m',linewidth=2)

plt.axvline(35.5,color='k',linewidth=2)
plt.axvline(37.5,color='k',linewidth=2)

plt.axvline(41.5,color='r',linewidth=2)
plt.axvline(39.5,color='r',linewidth=2)

### Xenon area
plt.axvline(64,color='k',linewidth=2)
plt.axvline(74,color='k',linewidth=2)

plt.axvline(128,color='r',linewidth=2)
plt.axvline(140,color='r',linewidth=2)

plt.show()
# Out:
# //anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
dx= XeArCon[:,0][1]-XeArCon[:,0][0]
dx=1

# %%
argon1 = np.sum(XeArCon[:,1][Ar1:Ar2])*dx
argon2 = np.sum(XeArCon[:,1][Ar3:Ar4])*dx
argon3 = np.sum(XeArCon[:,1][Ar5:Ar6])*dx
Xenon1 = np.sum(XeArCon[:,1][Xe1:Xe2])*dx
Xenon2 = np.sum(XeArCon[:,1][Xe3:Xe4])*dx

print("Xenon with tiny ammount of argon")
print("Argon area ", argon1+argon2+argon3)
print()
print("Xenon area ", Xenon1+Xenon2)
# Out:
# Xenon with tiny ammount of argon
# Argon area  5.69212e-06
#
# Xenon area  1.957047e-05

# %%
(argon1+argon2+argon3)/(Xenon1+Xenon2)*100
# Out:
# 29.085249357833508

# %%
argon1 = np.sum(XeArCon[:,1][Ar1:Ar2])-np.sum(XeArConB[:,1][Ar1:Ar2])
argon2 = np.sum(XeArCon[:,1][Ar3:Ar4])-np.sum(XeArConB[:,1][Ar3:Ar4])
argon3 = np.sum(XeArCon[:,1][Ar5:Ar6])-np.sum(XeArConB[:,1][Ar5:Ar6])
Xenon1 = np.sum(XeArCon[:,1][Xe1:Xe2])
Xenon2 = np.sum(XeArCon[:,1][Xe3:Xe4])

# %%
(argon1+argon2+argon3)/(Xenon1+Xenon2)*100
# Out:
# 29.085249357833508

# %%
plt.figure(figsize=(15,9))
plt.semilogy(XeArCon[:,0],XeArCon[:,1],color='k',alpha=0.8)
plt.semilogy(ArXe[:,0],ArXe[:,1],color='b',alpha=0.8)

#plt.semilogy(amu2,torr2,color='steelblue',linewidth=2,label='Day2-Baking')
plt.xlabel('Mass / amu',fontsize=26)

plt.ylabel('Torr',fontsize=26)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.xticks(np.arange(0, 140, 20))
plt.xlim(10,140)
plt.ylim(1e-9,3e-5)
plt.grid()
plt.legend(loc='upper left',fontsize=20)
plt.tight_layout()


plt.show()
# Out:
# //anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
files = os.listdir("*.txt")
name=[]
for x in range(0,len(files)):
    name.append(files[x].replace('.txt',''))

# %%
data = dict()
for x in range(0,len(files)):
    holder = pd.read_table(files[x],skiprows=20,names=['data']) 
    data[x] = pd.DataFrame(holder.data.str.split(',',1).tolist(),columns = ['amu','torr'])
    data[x]['amu'] = pd.to_numeric(data[x]['amu'], errors='coerce')
    data[x]['torr'] = pd.to_numeric(data[x]['torr'].str.replace(',', ''), errors='coerce')

# %%
plt.figure(figsize=(15,9))
#for x in range(0,len(files)):
for x in [1,3]:
    plt.semilogy(data[x]['amu'],data[x]['torr'],linewidth=2,label=name[x],color=cm.hot((x)/6))
#plt.semilogy(amu2,torr2,color='steelblue',linewidth=2,label='Day2-Baking')
plt.xlabel('Mass / amu',fontsize=26)

plt.ylabel('Torr',fontsize=26)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.xticks(np.arange(0, 51, 5.0))
#plt.xlim(0,60)
plt.ylim(4e-10,3e-6)
plt.grid()
plt.legend(loc='upper left',fontsize=20)
plt.tight_layout()
#plt.savefig('Rga-fill-4-25.pdf')

plt.show()

# %%
import numpy as np
import glob
import os
# %matplotlib inline
from readTRC import readTrc
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import chisquare
import numpy.polynomial.polynomial as poly

# %%
def find_nearest(array,value):
    idx = (np.abs(array-value)).argmin()
    return array[idx]

def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# %%
SPATH = '/Users/austinmcdonald/Desktop/XeHe/Data/100/'
PATH = '/Users/austinmcdonald/Desktop/XeHe/100/'
folders = glob.glob(PATH+"*/")
folders.sort()
folders
# Out:
# ['/Users/austinmcdonald/Desktop/XeHe/100/Xe-100_P-01_E-080/',
#  '/Users/austinmcdonald/Desktop/XeHe/100/Xe-100_P-01_E-100/',
#  '/Users/austinmcdonald/Desktop/XeHe/100/Xe-100_P-01_E-150/',
#  '/Users/austinmcdonald/Desktop/XeHe/100/Xe-100_P-01_E-200/',
#  '/Users/austinmcdonald/Desktop/XeHe/100/Xe-100_P-01_E-250/',
#  '/Users/austinmcdonald/Desktop/XeHe/100/Xe-100_P-01_E-300/']

# %%
len(folders)
# Out:
# 6

# %%
CHI = 0.25
for F in range(0,len(folders)):
    #print(folders[F])
    NAME = folders[F].split('/')[-2]
    print(NAME)
    files = os.listdir(folders[F])
    
    FilesGold   = []
    FilesSignal = []

    for x in range(0,len(files)):
        if int(files[x][1]) ==4 or int(files[x][1]) ==2:
            FilesGold.append(files[x])
        if int(files[x][1]) ==3 or int(files[x][1]) ==1:
            FilesSignal.append(files[x])
            
    X, Y, info = readTrc(folders[F]+FilesSignal[0])
    Yvals = np.zeros(X.shape[0])
    Xvals = np.zeros(Y.shape[0])
    avg = 0
    for w in range(0,len(FilesSignal)):

        X, Y, info = readTrc(folders[F]+FilesSignal[w])
        if Y.shape[0]==Yvals.shape[0] and X.shape[0]==Xvals.shape[0]:
            Yvals += Y
            Xvals += X
            avg   += 1
    MSigY = Yvals/avg
    MSigX = Xvals/avg
    
    
    X, Y, info = readTrc(folders[F]+FilesSignal[0])
    Yvals = np.zeros(X.shape[0])
    Xvals = np.zeros(Y.shape[0])
    avg = 0
    #for w in range(0,1100):
    for w in range(0,len(FilesSignal)):

        X, Y, info = readTrc(folders[F]+FilesSignal[w])
        if Y.shape[0]==Yvals.shape[0] and X.shape[0]==Xvals.shape[0]:
            CC = moving_average((MSigY-Y),50)
            xx = moving_average(X,50)
            coefs = poly.polyfit(xx, CC, 1)
            ffit = poly.polyval(xx, coefs)
            chi = abs(chisquare(CC, f_exp=ffit)[0])
            if chi <CHI:
                Yvals += Y
                Xvals += X
                avg   += 1
    SigY = Yvals/avg
    SigX = Xvals/avg
    print("Sig avg",avg)

    
    X, Y, info = readTrc(folders[F]+FilesGold[0])

    avg = 0
    for w in range(0,len(FilesGold)):

        X, Y, info = readTrc(folders[F]+FilesGold[w])
        if Y.shape[0]==Yvals.shape[0] and X.shape[0]==Xvals.shape[0]:
            Yvals += Y
            Xvals += X
            avg   += 1
    MGolY = Yvals/avg
    MGolX = Xvals/avg
    
    
    X, Y, info = readTrc(folders[F]+FilesGold[0])  
    Yvals = np.zeros(X.shape[0])
    Xvals = np.zeros(Y.shape[0])
    avg = 0 
    #for w in range(0,1100):
    for w in range(0,len(FilesGold)):
        X, Y, info = readTrc(folders[F]+FilesGold[w])
        if Y.shape[0]==Yvals.shape[0] and X.shape[0]==Xvals.shape[0]:
            CC = moving_average((MGolY-Y),50)
            xx = moving_average(X,50)
            coefs = poly.polyfit(xx, CC, 1)
            ffit = poly.polyval(xx, coefs)
            chi = abs(chisquare(CC, f_exp=ffit)[0])
            if chi <CHI:
                Yvals += Y
                Xvals += X
                avg   += 1
    GolY = Yvals/avg
    GolX = Xvals/avg
    print("Gol avg",avg)


    TriggerTime = find_nearest(SigX,0)
    Trigger     = np.where(SigX==TriggerTime)[0][0]
    baselineS    = np.mean(SigY[0:Trigger])
    baselineG    = np.mean(GolY[0:Trigger])
    data = [(GolX), GolY-baselineG, SigY-baselineS]
    np.savetxt(SPATH+NAME+'.txt',data)
    #print("DONE!")
# Out:
# Xe-100_P-01_E-080
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8c4d928b4884> in <module>()
#      45             chi = abs(chisquare(CC, f_exp=ffit)[0])
#      46             if chi <CHI:
# ---> 47                 mm.append(chi)
#      48                 Yvals += Y
#      49                 Xvals += X
#
# NameError: name 'mm' is not defined

# %%
from scipy import stats
from scipy.stats import chisquare
import numpy.polynomial.polynomial as poly

#slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)

# %%
import numpy.polynomial.polynomial as poly

#coefs = poly.polyfit(x, y, 4)
#ffit = poly.polyval(x_new, coefs)

# %%
F=-1   #print(folders[F])
NAME = folders[F].split('/')[-2]
NAME
# Out:
# 'Xe-100_P-11_E-350'

# %%
files = os.listdir(folders[F])

FilesGold   = []
FilesSignal = []

for x in range(0,len(files)):
    if int(files[x][1]) ==4 or int(files[x][1]) ==2:
        FilesGold.append(files[x])
    if int(files[x][1]) ==3 or int(files[x][1]) ==1:
        FilesSignal.append(files[x])
mm=[]

X, Y, info = readTrc(folders[F]+FilesGold[0])

Yvals = np.zeros(X.shape[0])
Xvals = np.zeros(Y.shape[0])
avg = 0
#for w in range(0,10):
for w in range(0,len(FilesGold)):
    X, Y, info = readTrc(folders[F]+FilesGold[w])
    if Y.shape[0]==Yvals.shape[0] and X.shape[0]==Xvals.shape[0]:
        CC = moving_average((GolY-Y),50)
        xx = moving_average(X,50)
        coefs = poly.polyfit(xx, CC, 1)
        ffit = poly.polyval(xx, coefs)
        chi = abs(chisquare(CC, f_exp=ffit)[0])
        print(chi)
        plt.plot(xx,CC)
        plt.plot(xx,ffit)
        plt.show()
        mm.append(chi)

        if chi <0.5:
            #mm.append(chi)
            Yvals += Y
            Xvals += X
            avg   += 1
GGolY = Yvals/avg
GGolX = Xvals/avg
# Out:
# 0.959513178422
# 1.01874843715
# 4.0697376317
# 0.760524770236
# 0.514140929801
# 0.405163045504
# 0.62243424353
# 0.446381186838
# 0.446990843373
# 0.369613323922
# 1.94169242636
# 0.518499913001
# 0.459073355786
# 0.707946176336
# 0.4495672561
# 0.948289878129
# 0.350095091191
# 1.79734120128
# 0.623967306254
# 0.439450991608
# 2.81028555991
# 1.53742377251
# 0.474189647622
# 0.174862569362
# 0.467818922799
# 75.0115251039
# 0.369458809724
# 1.35004938631
# 2.36214388548
# 16.686405238
# 0.136848319284
# 0.578661189347
# 0.597037362683
# 0.805531283905
# 0.262605553829
# 0.0920254779889
# 0.809085065562
# 1.46690822263
# 0.174614486003
# 0.281871763234
# 0.336536129438
# 0.207236437697
# 0.524690961721
# 103.55649624
# 0.245779898439
# 0.343506175635
# 3.50327090761
# 1.75570344218
# 0.173130041198
# 0.667357127822
# 0.249243832812
# 0.180758870724
# 12.4774624578
# 3.16962393324
# 0.169337459508
# 0.556494693922
# 0.33371646081
# 0.146363198058
# 0.670560436295
# 0.799642720578
# 0.467472578667
# 0.187670136875
# 0.926284634493
# 0.556879236784
# 0.206593384215
# 0.869332966574
# 0.550169931924
# 1.52985304167
# 0.0641335306355
# 0.0640703586295
# 1.0938706676
# 1.54973265901
# 0.0725374113564
# 1.0183207576
# 0.244009681344
# 0.215421075417
# 0.0409101035005
# 0.098569848622
# 3.64874475615
# 0.416475324125
# 0.52026999258
# 2.15790122
# 0.421235695347
# 0.536305195553
# 0.660275193837
# 0.366456755176
# 1.70797152637
# 0.48063654025
# 0.378264093085
# 1.57672241886
# 1.02187203475
# 0.935844678574
# 0.295586984873
# 0.549503567764
# 0.834213727459
# 0.989693139728
# 0.36081592494
# 0.226507428437

# %%
avg
# Out:
# 10

# %%
plt.plot(GolX,GolY,alpha=0.4)
plt.plot(GGolX,GGolY,color='r')

# %%
plt.plot(GolX,GolY,alpha=0.4)

# %%
#SSigX3 =SSigX
#SSigY3 =SSigY

plt.plot(SSigX,SSigY,color='r')

plt.plot(SigX,SigY,alpha=0.4)

# %%
plt.plot(SigX,SigY-Y)
plt.plot(X,Y)

# %%
np.linspace(0,10,100)
# Out:
# array([  0.        ,   0.1010101 ,   0.2020202 ,   0.3030303 ,
#          0.4040404 ,   0.50505051,   0.60606061,   0.70707071,
#          0.80808081,   0.90909091,   1.01010101,   1.11111111,
#          1.21212121,   1.31313131,   1.41414141,   1.51515152,
#          1.61616162,   1.71717172,   1.81818182,   1.91919192,
#          2.02020202,   2.12121212,   2.22222222,   2.32323232,
#          2.42424242,   2.52525253,   2.62626263,   2.72727273,
#          2.82828283,   2.92929293,   3.03030303,   3.13131313,
#          3.23232323,   3.33333333,   3.43434343,   3.53535354,
#          3.63636364,   3.73737374,   3.83838384,   3.93939394,
#          4.04040404,   4.14141414,   4.24242424,   4.34343434,
#          4.44444444,   4.54545455,   4.64646465,   4.74747475,
#          4.84848485,   4.94949495,   5.05050505,   5.15151515,
#          5.25252525,   5.35353535,   5.45454545,   5.55555556,
#          5.65656566,   5.75757576,   5.85858586,   5.95959596,
#          6.06060606,   6.16161616,   6.26262626,   6.36363636,
#          6.46464646,   6.56565657,   6.66666667,   6.76767677,
#          6.86868687,   6.96969697,   7.07070707,   7.17171717,
#          7.27272727,   7.37373737,   7.47474747,   7.57575758,
#          7.67676768,   7.77777778,   7.87878788,   7.97979798,
#          8.08080808,   8.18181818,   8.28282828,   8.38383838,
#          8.48484848,   8.58585859,   8.68686869,   8.78787879,
#          8.88888889,   8.98989899,   9.09090909,   9.19191919,
#          9.29292929,   9.39393939,   9.49494949,   9.5959596 ,
#          9.6969697 ,   9.7979798 ,   9.8989899 ,  10.        ])

# %%
plt.hist(mm,bins=np.linspace(0,10,100))
plt.show()

# %%
mm
# Out:
# [-8.6632362833494268e-05,
#  0.00021975424112255021,
#  0.00025461184890802495,
#  0.00037312979829514845,
#  8.0292566233009722e-05,
#  0.00013253211228975942,
#  -0.0003242931365605732,
#  -8.82501662337128e-06,
#  -0.00033297889840493708,
#  -0.00020411926854844507,
#  0.00032684739345539653,
#  -3.147673366352889e-05,
#  -0.00029766304898738559,
#  5.4912228565485995e-05,
#  2.4605793353137199e-05,
#  -0.00014938022268036764,
#  -3.7635295054326122e-06,
#  -3.7746312356942619e-05,
#  -0.00030736943992137498,
#  -0.00024426748426789683,
#  0.00019483214508710325,
#  0.00033430423455919092,
#  -0.00047130538379683295,
#  5.8796867855591195e-05,
#  0.00020262225283240802,
#  0.00031068396134214382,
#  -3.118512535220732e-05,
#  -0.00047495048768835256,
#  2.4553720440401201e-05,
#  3.4926644657411306e-05,
#  -9.9775566008059282e-05,
#  -0.00019659993994936746,
#  4.0258910921577148e-05,
#  3.4301769704579372e-05,
#  -7.898118776670575e-06,
#  -0.00025224505449905117,
#  5.6422343034829847e-05,
#  -0.00046374439686756652,
#  3.6009761242320001e-05,
#  0.00014491505093837891,
#  0.00028339775506848268,
#  0.00035668517245312137,
#  0.00014925793186056085,
#  1.7148952249342779e-05,
#  -0.00038096929478242963,
#  -0.00048949965950678936,
#  6.9253108732978888e-05,
#  -7.266640763770053e-05,
#  -1.8854259616323817e-05,
#  -0.00014550599797280965,
#  7.1815096039589817e-05,
#  0.00014964327141480722,
#  -0.0001090133007274247,
#  0.00033300241174079109,
#  3.7748996527702207e-05,
#  4.4247696037154317e-05,
#  -0.00012468724746095904,
#  0.00029143781279492026,
#  -9.9931784746267266e-05,
#  -6.1522804312197707e-05,
#  -0.00026436762858399074,
#  -0.00016110704262851361,
#  -0.00014616211667328318,
#  7.9074060074987461e-05,
#  7.6116318631582952e-05,
#  -0.00029515313459351069,
#  0.0001363959224147702,
#  3.1250297018250097e-05,
#  -0.00047350286071429188,
#  0.00015004944013414796,
#  -1.0557380431608962e-06,
#  -0.00032690719677992014,
#  -0.0003365927585488151,
#  0.0002466655224245122,
#  -0.00010865920492081995,
#  0.00021886900160603831,
#  8.3729378473585369e-05,
#  -0.00041246299240515913,
#  3.857174854893093e-05,
#  0.0001630155954054106,
#  0.00021396373322630762,
#  0.00023153313398343217,
#  -5.8617135781529227e-05,
#  -3.8371187309774566e-05,
#  0.00093488196630850992,
#  0.00032970098907332903,
#  8.754111568586015e-05,
#  -1.0189326937054335e-05,
#  7.7511872692907627e-05,
#  -1.3719870420554764e-05,
#  -0.0001024416991401422,
#  9.1196634159926976e-05,
#  -0.00027778161090478287,
#  0.00022699237599285344,
#  4.82052374050899e-05,
#  0.0001886042247238783,
#  0.00015914137069785261]

# %%
AH = 3
files = os.listdir(folders[AH])
len(files)
# Out:
# 200

# %%
FilesGold   = []
FilesSignal = []

for x in range(0,len(files)):
    if int(files[x][1]) ==4 or int(files[x][1]) ==2:
        FilesGold.append(files[x])
    if int(files[x][1]) ==3 or int(files[x][1]) ==1:
        FilesSignal.append(files[x])

# %%
X, Y, info = readTrc(folders[AH]+FilesSignal[0])

Yvals = np.zeros(X.shape[0])
Xvals = np.zeros(Y.shape[0])
avg = 0
#for w in range(0,1100):
for w in range(0,len(FilesSignal)):

    X, Y, info = readTrc(folders[AH]+FilesSignal[w])
    if Y.shape[0]==Yvals.shape[0] and X.shape[0]==Xvals.shape[0]:
        Yvals += Y
        Xvals += X
        avg   += 1
SigY = Yvals/avg
SigX = Xvals/avg

X, Y, info = readTrc(folders[AH]+FilesGold[0])

Yvals = np.zeros(X.shape[0])
Xvals = np.zeros(Y.shape[0])
avg = 0
#for w in range(0,1100):
for w in range(0,len(FilesGold)):
    X, Y, info = readTrc(folders[AH]+FilesGold[w])
    if Y.shape[0]==Yvals.shape[0] and X.shape[0]==Xvals.shape[0]:
        Yvals += Y
        Xvals += X
        avg   += 1
GolY = Yvals/avg
GolX = Xvals/avg

# %%
TriggerTime = find_nearest(SigX,0)
Trigger     = np.where(SigX==TriggerTime)[0][0]
baselineS    = np.mean(SigY[0:Trigger])
baselineG    = np.mean(GolY[0:Trigger])
data = [GolX, GolY-baselineG, SigY-baselineS]
np.savetxt(PATH+"test"+'.txt',data)

# %%
plt.plot(GolX,SigY-baselineS+0.001)
plt.plot(GolX,GolY-baselineG)

# %%
AH = 3
Fold = folders[AH].split('/')[-2]
cut = Fold+'/'



files = os.listdir(folders[AH])
#files.remove('.DS_Store')
int(files[4][1])
# Out:
# 4

# %%
Fold
# Out:
# '250'

# %%
FilesGold   = []
FilesSignal = []

for x in range(0,len(files)):
    if int(files[x][1]) ==4 or int(files[x][1]) ==2:
        FilesGold.append(files[x])
    if int(files[x][1]) ==3 or int(files[x][1]) ==1:
        FilesSignal.append(files[x])

# %%
X, Y, info = readTrc(folders[AH]+FilesSignal[0])

Yvals = np.zeros(X.shape[0])
Xvals = np.zeros(Y.shape[0])
avg = 0
#for w in range(0,1100):
for w in range(0,len(FilesSignal)):

    X, Y, info = readTrc(folders[AH]+FilesSignal[w])
    if Y.shape[0]==Yvals.shape[0] and X.shape[0]==Xvals.shape[0]:
        Yvals += Y
        Xvals += X
        avg   += 1
SigY = Yvals/avg
SigX = Xvals/avg

# %%
avg
# Out:
# 93

# %%
TriggerTime = find_nearest(SigX,0)
Trigger     = np.where(SigX==TriggerTime)[0][0]
baseline    = np.mean(SigY[0:Trigger])
data = [SigX,SigY-baseline]
np.savetxt('/Users/austinmcdonald/Desktop/Xenon-11bar-test/'+"Sig-"+Fold+'.txt',data)

# %%
X, Y, info = readTrc(folders[AH]+FilesGold[1])

Yvals = np.zeros(X.shape[0])
Xvals = np.zeros(Y.shape[0])
avg = 0
#for w in range(0,1100):
for w in range(0,len(FilesGold)):
    X, Y, info = readTrc(folders[AH]+FilesGold[w])
    if Y.shape[0]==Yvals.shape[0] and X.shape[0]==Xvals.shape[0]:
        Yvals += Y
        Xvals += X
        avg   += 1
GolY = Yvals/avg
GolX = Xvals/avg

# %%
avg
# Out:
# 93

# %%
TriggerTime = find_nearest(GolX,0)
Trigger     = np.where(GolX==TriggerTime)[0][0]
baseline    = np.mean(GolY[0:Trigger])
data = [GolX,GolY-baseline]
np.savetxt('/Users/austinmcdonald/Desktop/Xenon-11bar-test/'+"Gol-"+Fold+'.txt',data)

# %%
for q in range(3,4):
    files = os.listdir(folders[q])
    Name = folders[q].split('/')[-2]
    N = len(files)
    
    X, Y, info = readTrc(folders[q]+files[0])
    
    Yvals = np.zeros(X.shape[0])
    Xvals = np.zeros(Y.shape[0])
    avg = 0
    for w in range(0,N):
        X, Y, info = readTrc(folders[q]+files[w])
        if Y.shape[0]==Yvals.shape[0] and X.shape[0]==Xvals.shape[0]:
            Yvals += Y
            Xvals += X
            avg   += 1
    Yvals = Yvals/avg
    Xvals = Xvals/avg
    TriggerTime = find_nearest(Xvals,0)
    Trigger     = np.where(Xvals==TriggerTime)[0][0]
    baseline    = np.mean(Yvals[0:Trigger])
    data = [Xvals,Yvals-baseline]
    np.savetxt(PATH+Name+'.txt',data)

# %%
Yvals
# Out:
# array([ 0.01477493,  0.01506118,  0.01478548, ...,  0.01492791,
#         0.01496623,  0.01486933])

# %%
files = os.listdir()
#files.remove('.DS_Store')

# %%
len(files)

# %%
N = len(files)
Yvals = np.zeros(50e3+2)
Xvals = np.zeros(50e3+2)

for q in range(0,N):
    X, Y, info = readTrc(files[q])
    #Y = np.array(Y)
    Yvals += Y
    Xvals +=X
Yvals = Yvals/N
Xvals = Xvals/N

# %%
find_nearest(Xvals,0)

# %%
TriggerTime = find_nearest(Xvals,0)
Trigger     = np.where(Xvals==TriggerTime)[0][0]
baseline    = np.mean(Yvals[0:Trigger])
baseline

# %%
plt.plot(Xvals,Yvals-baseline)

# %%
data = [Xvals,Yvals-baseline]

# %%
path = '/Users/austinmcdonald/Desktop/data/Ion-stuff/Ion mobilitys/Argon/090418-cleaned-2bar/'
np.savetxt(path+'050-clean.txt',data)

# %%
AA = np.loadtxt(path+'200clean.txt')

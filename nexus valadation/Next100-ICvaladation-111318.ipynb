# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
# %matplotlib inline

# %%
Bi214CNT = np.array([14966, 8677, 832,  116,  22])
Tl208CNT = np.array([21241, 11170,150,  27,   4])
bb0nuCNT = np.array([6820,  6020, 3892, 3147, 2289])


Bi214IC = np.array([14890, 11864 , 2559 , 383 , 21])
Tl208IC = np.array([20805, 17338, 2190, 289  , 5])
#bb0nuIC = np.array([6835,6125,4089,3220,2221])
bb0nuIC = np.array([6831, 6552, 4358, 3480, 2454])

# %%
# data to plot
n_groups = 5
plt.rcParams.update({'font.size': 22})
# create plot
fig, ax = plt.subplots(figsize=(14,8))
index = 2*np.arange(n_groups)
bar_width = 0.25
opacity = 0.7
F = 1e4
 
rects1 = plt.barh(index-.1, bb0nuCNT[::-1]/F,bar_width,xerr=np.sqrt(bb0nuCNT[::-1])/F
                  ,alpha=opacity,color='darkorchid',label='Bi214 Centia',
                  error_kw=dict(ecolor='r', lw=2, capsize=5, capthick=1))
rects1 = plt.barh(index+bar_width-.1, bb0nuIC[::-1]/F,bar_width,xerr=np.sqrt(bb0nuIC[::-1])/F
                  ,alpha=.3,color='darkorchid',label='Bi214 IC',
                 error_kw=dict(ecolor='r', lw=2, capsize=5, capthick=1))

#ax.set_xscale('log')
names = ['Broad energy', 'Fiducal Filter', 'Track Filter', 'Blob Filter', 'ROI']
names = ['Energy', 'Fiducal', 'Track', 'Blob', 'ROI']

plt.yticks(index + 1.5*bar_width, names[::-1],fontsize=24,rotation=-10)
plt.ylim(-0.5,9.25)
plt.xlim(0.1,.8)
#plt.ylim(2e-7,5e-4)

plt.xlabel("Pass Ratio",fontsize=26)
plt.ylabel("Cuts",fontsize=26)
plt.tick_params('both', length=10, width=2, which='major')
plt.tick_params('both', length=5, width=1, which='minor')
plt.xticks(fontsize=24)
plt.legend(loc='lower right',fontsize=20,shadow=True, fancybox=True,ncol=1)

plt.tight_layout()
#plt.savefig('/Users/austinmcdonald/Desktop/CutsNewVsOldS.pdf')
plt.show()

# %%
# data to plot
n_groups = 5
plt.rcParams.update({'font.size': 22})
# create plot
fig, ax = plt.subplots(figsize=(10,8))
index = 2*np.arange(n_groups)
bar_width = 0.25
opacity = 0.7
F = 1e7
 
rects1 = plt.barh(index-.2, Bi214CNT[::-1]/F,bar_width,alpha=opacity,color='b',label='Bi214 Centia')
rects1 = plt.barh(index+bar_width-.2, Bi214IC[::-1]/F,bar_width,alpha=.4,color='b',label='Bi214 IC')

rects1 = plt.barh(index+2*bar_width, Tl208CNT[::-1]/F,bar_width,alpha=opacity,color='g',label='Tl208 Centia')
rects1 = plt.barh(index+2*bar_width+bar_width, Tl208IC[::-1]/F,bar_width,alpha=.4,color='g',label='Tl208 IC')

ax.set_xscale('log')
names = ['Broad energy', 'Fiducal Filter', 'Track Filter', 'Blob Filter', 'ROI']
names = ['Energy', 'Fiducal', 'Track', 'Blob', 'ROI']

plt.yticks(index + 1.5*bar_width, names[::-1],fontsize=24,rotation=-10)
plt.ylim(-0.5,9.25)
plt.xlim(2e-7,5e-3)
#plt.ylim(2e-7,5e-4)

plt.xlabel("Pass Ratio",fontsize=26)
plt.ylabel("Cuts",fontsize=26)
plt.tick_params('both', length=10, width=2, which='major')
plt.tick_params('both', length=5, width=1, which='minor')
plt.xticks(fontsize=24)
plt.legend(loc='lower right',fontsize=20,shadow=True, fancybox=True,ncol=1)

plt.tight_layout()
#plt.savefig('/Users/austinmcdonald/Desktop/CutsNewVsOld.pdf')
plt.show()

# %%
### JAVI
Bi214CNT = np.array([14968, 8724, 839,  118,  25])
Tl208CNT = np.array([ 21254,11273,  163,29,6])
#bb0nuCNT = np.array([6820,  6020, 3892, 3147, 2289])


Bi214IC = np.array([14921, 8872 , 902 , 150 , 36])
Tl208IC = np.array([21225, 11692, 178, 40  , 6])
#bb0nuIC = np.array([6831, 6552, 4358, 3480, 2454])
# data to plot
n_groups = 5
plt.rcParams.update({'font.size': 22})
# create plot
fig, ax = plt.subplots(figsize=(10,8))
index = 2*np.arange(n_groups)
bar_width = 0.25
opacity = 0.7
F = 1e7
 
rects1 = plt.barh(index-.2, Bi214CNT[::-1]/F,bar_width,alpha=opacity,color='b',label='Bi214 Centia')
rects1 = plt.barh(index+bar_width-.2, Bi214IC[::-1]/F,bar_width,alpha=.4,color='b',label='Bi214 IC')

rects1 = plt.barh(index+2*bar_width, Tl208CNT[::-1]/F,bar_width,alpha=opacity,color='g',label='Tl208 Centia')
rects1 = plt.barh(index+2*bar_width+bar_width, Tl208IC[::-1]/F,bar_width,alpha=.4,color='g',label='Tl208 IC')

ax.set_xscale('log')
names = ['Broad energy', 'Fiducal Filter', 'Track Filter', 'Blob Filter', 'ROI']
names = ['Energy', 'Fiducal', 'Track', 'Blob', 'ROI']

plt.yticks(index + 1.5*bar_width, names[::-1],fontsize=24,rotation=-10)
plt.ylim(-0.5,9.25)
plt.xlim(2e-7,5e-3)
#plt.ylim(2e-7,5e-4)

plt.xlabel("Pass Ratio",fontsize=26)
plt.ylabel("Cuts",fontsize=26)
plt.tick_params('both', length=10, width=2, which='major')
plt.tick_params('both', length=5, width=1, which='minor')
plt.xticks(fontsize=24)
plt.legend(loc='lower right',fontsize=20,shadow=True, fancybox=True,ncol=1)

plt.tight_layout()
#plt.savefig('/Users/austinmcdonald/Desktop/CutsNewVsOld.pdf')
plt.show()

# %%
Bi214 = np.array([380,326,48,9,4])/1e7
Tl208 = np.array([6272,3977,150,30,8])/1e7
bb0nu = np.array([7572,6694,4676,3820,3401])/1e4

# %%
back = bb0nu/(Bi214+Tl208)

# %%
# data to plot
n_groups = 5
plt.rcParams.update({'font.size': 22})
# create plot
fig, ax = plt.subplots(figsize=(8,8))
index = 2*np.arange(n_groups)
bar_width = 0.25
opacity = 0.7
 
rects1 = plt.bar(index, Bi214, bar_width,alpha=opacity,color='b',label='Bi214')
rects1 = plt.bar(index+bar_width, Tl208, bar_width,alpha=opacity,color='g',label='Tl208')
rects1 = plt.bar(index+2*bar_width, bb0nu, bar_width,alpha=opacity,color='m',label='bb0nu')
#rects1 = plt.scatter(index+3*bar_width, back, bar_width,alpha=opacity,color='grey',label='ratio')

ax.set_yscale('log')
names = ['Broad energy', 'Fiducal Filter', 'Track Filter', 'Blob Filter', 'ROI']
names = ['Energy', 'Fiducal', 'Track', 'Blob', 'ROI']

plt.xticks(index + 1.5*bar_width, names,fontsize=24,rotation=-10)
plt.xlim(-0.5,9.25)
plt.ylim(2e-7,5)
#plt.ylim(2e-7,5e-4)

plt.ylabel("Pass Ratio",fontsize=26)
plt.xlabel("Cuts",fontsize=26)
plt.tick_params('both', length=10, width=2, which='major')
plt.tick_params('both', length=5, width=1, which='minor')
plt.yticks(fontsize=24)
plt.legend(loc='upper right',fontsize=20,shadow=True, fancybox=True,ncol=3)

plt.tight_layout()
#plt.savefig('/Users/austinmcdonald/Desktop/Cuts.pdf')
plt.show()

# %%
# data to plot
n_groups = 5
plt.rcParams.update({'font.size': 22})
# create plot
fig, ax = plt.subplots(figsize=(8,8))
index = 2*np.arange(n_groups)
bar_width = 0.25
opacity = 0.7
 
rects1 = plt.bar(index, Bi214CNT/1e7, bar_width,alpha=opacity,color='b',label='Bi214')
rects1 = plt.bar(index+bar_width, Tl208CNT/1e7, bar_width,alpha=opacity,color='g',label='Tl208')
rects1 = plt.bar(index+2*bar_width, bb0nuCNT/1e4, bar_width,alpha=opacity,color='m',label='bb0nu')
#rects1 = plt.scatter(index+3*bar_width, back, bar_width,alpha=opacity,color='grey',label='ratio')

ax.set_yscale('log')
names = ['Broad energy', 'Fiducal Filter', 'Track Filter', 'Blob Filter', 'ROI']
names = ['Energy', 'Fiducal', 'Track', 'Blob', 'ROI']

plt.xticks(index + 1.5*bar_width, names,fontsize=24,rotation=-10)
plt.xlim(-0.5,9.25)
plt.ylim(2e-7,5)
#plt.ylim(2e-7,5e-4)

plt.ylabel("Pass Ratio",fontsize=26)
plt.xlabel("Cuts",fontsize=26)
plt.tick_params('both', length=10, width=2, which='major')
plt.tick_params('both', length=5, width=1, which='minor')
plt.yticks(fontsize=24)
plt.legend(loc='upper right',fontsize=20,shadow=True, fancybox=True,ncol=3)

plt.tight_layout()
#plt.savefig('/Users/austinmcdonald/Desktop/Cuts.pdf')
plt.show()

# %%
Bi214
# Out:
# array([  3.80000000e-05,   3.26000000e-05,   4.80000000e-06,
#          9.00000000e-07,   4.00000000e-07])

# %%
np.sqrt(380)
# Out:
# 19.493588689617926

# %%
Bi214 = np.array([380,326,48,9,4])
Tl208 = np.array([6272,3977,150,30,8])
bb0nu = np.array([7572,6694,4676,3820,3401])

Bi2142 = np.array([382,285,49,15,4])
Tl2082 = np.array([6246,3370,129,45,12])
bb0nu2 = np.array([7572,6012,4411,4025,4016])

# %%
# data to plot
n_groups = 5
plt.rcParams.update({'font.size': 22})
# create plot
fig, ax = plt.subplots(figsize=(8,8))
index = np.arange(n_groups)

fact = 1e7
#plt.plot(index, Bi214/fact, alpha=opacity,color='b',label='Bi214')
plt.errorbar(index,Bi214/fact,yerr=np.sqrt(Bi214)/fact,alpha=0.9
             ,fmt='^',markersize=7,linewidth=1.4)

#plt.plot(index, Tl208/fact,alpha=opacity,color='g',label='Tl208')
plt.errorbar(index,Tl208/fact,yerr=np.sqrt(Tl208)/fact,alpha=0.9
             ,fmt='^',markersize=7,linewidth=1.4)


#plt.plot(index, Bi214/fact, alpha=opacity,color='k',label='Bi214')
plt.errorbar(index,Bi214/fact,yerr=np.sqrt(Bi214)/fact,alpha=0.9
             ,fmt='p',markersize=7,linewidth=1.4,color='k')

#plt.plot(index, Tl208/fact,alpha=opacity,color='r',label='Tl208')
plt.errorbar(index,Tl208/fact,yerr=np.sqrt(Tl208)/fact,alpha=0.9
             ,fmt='p',markersize=7,linewidth=1.4,color='r')
#rects1 = plt.bar(index+2*bar_width, bb0nu, bar_width,alpha=opacity,color='m',label='bb0nu')

ax.set_yscale('log')
names = ['Broad energy', 'Fiducal Filter', 'Track Filter', 'Blob Filter', 'ROI']
names = ['Energy', 'Fiducal', 'Track', 'Blob', 'ROI']

plt.xticks(index , names,fontsize=24,rotation=-10)
plt.xlim(-0.5,4.5)
plt.ylim(1e-7,1e-3)
#plt.ylim(2e-7,5e-4)

plt.ylabel("Pass Ratio",fontsize=26)
plt.xlabel("Cuts",fontsize=26)
plt.tick_params('both', length=10, width=2, which='major')
plt.tick_params('both', length=5, width=1, which='minor')
plt.yticks(fontsize=24)
plt.legend(loc='upper right',fontsize=20,shadow=True, fancybox=True)

plt.tight_layout()
#plt.savefig('/Users/austinmcdonald/Desktop/Cuts.pdf')
plt.show()
# Out:
# //anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# data to plot
n_groups = 5
plt.rcParams.update({'font.size': 22})
# create plot
fig, ax = plt.subplots(figsize=(8,8))
index = np.arange(n_groups)

fact = 1e4
plt.plot(index, bb0nu/fact, alpha=opacity,color='b',label='bb0nu')
plt.errorbar(index,bb0nu/fact,yerr=np.sqrt(bb0nu)/fact,alpha=0.9
             ,fmt='^',markersize=7,linewidth=1.4)


plt.plot(index, bb0nu2/fact,alpha=opacity,color='r',label='bb0nu2')
plt.errorbar(index,bb0nu2/fact,yerr=np.sqrt(bb0nu2)/fact,alpha=0.9
             ,fmt='p',markersize=7,linewidth=1.4,color='r')
#rects1 = plt.bar(index+2*bar_width, bb0nu, bar_width,alpha=opacity,color='m',label='bb0nu')

ax.set_yscale('log')
names = ['Broad energy', 'Fiducal Filter', 'Track Filter', 'Blob Filter', 'ROI']
names = ['Energy', 'Fiducal', 'Track', 'Blob', 'ROI']

plt.xticks(index , names,fontsize=24,rotation=-10)
plt.xlim(-0.5,4.5)
plt.ylim(3e-1,1)
#plt.ylim(2e-7,5e-4)

plt.ylabel("Pass Ratio",fontsize=26)
plt.xlabel("Cuts",fontsize=26)
plt.tick_params('both', length=10, width=2, which='major')
plt.tick_params('both', length=5, width=1, which='minor')
plt.yticks(fontsize=24)
plt.legend(loc='upper right',fontsize=20,shadow=True, fancybox=True)

plt.tight_layout()
#plt.savefig('/Users/austinmcdonald/Desktop/Cuts.pdf')
plt.show()

# %%
Bi214 = np.array([380,326,48,9,4])
Tl208 = np.array([6272,3977,150,30,8])
bb0nu = np.array([7572,6694,4676,3820,3401])

'''Bi2142 = np.array([382,327,53,17,10])
Tl2082 = np.array([6231,3435,126,46,12])
bb0nu2 = np.array([7573,6743,4907,4491,4483])
'''
Bi2142 = np.array([382,327,53,7,4])
Tl2082 = np.array([6231,3435,126,27,7])
bb0nu2 = np.array([7573,6743,4907,4161,4152])

# %%
# data to plot
n_groups = 5
plt.rcParams.update({'font.size': 22})
# create plot
fig, ax = plt.subplots(figsize=(14,8))
index = 2*np.arange(n_groups)
bar_width = 0.25
opacity = 0.7
F = 1e7
 
rects1 = plt.barh(index-.2, Bi214[::-1]/F,bar_width,xerr=np.sqrt(Bi214[::-1])/F
                  ,alpha=opacity,color='b',label='Bi214 Centia',
                  error_kw=dict(ecolor='r', lw=2, capsize=5, capthick=1))
rects1 = plt.barh(index+bar_width-.2, Bi2142[::-1]/F,bar_width,xerr=np.sqrt(Bi2142[::-1])/F
                  ,alpha=.4,color='b',label='Bi214 IC',
                 error_kw=dict(ecolor='r', lw=2, capsize=5, capthick=1))

rects1 = plt.barh(index+2*bar_width, Tl208[::-1]/F,bar_width,xerr=np.sqrt(Tl208[::-1])/F
                  ,alpha=opacity,color='g',label='Tl208 Centia',
                  error_kw=dict(ecolor='r', lw=2, capsize=5, capthick=1))
rects1 = plt.barh(index+2*bar_width+bar_width, Tl2082[::-1]/F,bar_width,xerr=np.sqrt(Tl2082[::-1])/F
                  ,alpha=.4,color='g',label='Tl208 IC',
                 error_kw=dict(ecolor='r', lw=2, capsize=5, capthick=1))

ax.set_xscale('log')
names = ['Broad energy', 'Fiducal Filter', 'Track Filter', 'Blob Filter', 'ROI']
names = ['Energy', 'Fiducal', 'Track', 'Blob', 'ROI']

plt.yticks(index + 1.5*bar_width, names[::-1],fontsize=24,rotation=-10)
plt.ylim(-0.5,9.25)
plt.xlim(2e-7,1e-3)
#plt.ylim(2e-7,5e-4)

plt.xlabel("Pass Ratio",fontsize=26)
plt.ylabel("Cuts",fontsize=26)
plt.tick_params('both', length=10, width=2, which='major')
plt.tick_params('both', length=5, width=1, which='minor')
plt.xticks(fontsize=24)
plt.legend(loc='lower right',fontsize=20,shadow=True, fancybox=True,ncol=1)

plt.tight_layout()
#plt.savefig('/Users/austinmcdonald/Desktop/CutsNewVsOld.pdf')
plt.show()

# %%
# data to plot
n_groups = 5
plt.rcParams.update({'font.size': 22})
# create plot
fig, ax = plt.subplots(figsize=(14,8))
index = 2*np.arange(n_groups)
bar_width = 0.25
opacity = 0.7
F = 1e4
 
rects1 = plt.barh(index-.1, bb0nu[::-1]/F,bar_width,xerr=np.sqrt(bb0nu[::-1])/F
                  ,alpha=opacity,color='darkorchid',label='Bi214 Centia',
                  error_kw=dict(ecolor='r', lw=2, capsize=5, capthick=1))
rects1 = plt.barh(index+bar_width-.1, bb0nu2[::-1]/F,bar_width,xerr=np.sqrt(bb0nu2[::-1])/F
                  ,alpha=.3,color='darkorchid',label='Bi214 IC',
                 error_kw=dict(ecolor='r', lw=2, capsize=5, capthick=1))

#ax.set_xscale('log')
names = ['Broad energy', 'Fiducal Filter', 'Track Filter', 'Blob Filter', 'ROI']
names = ['Energy', 'Fiducal', 'Track', 'Blob', 'ROI']

plt.yticks(index + 1.5*bar_width, names[::-1],fontsize=24,rotation=-10)
plt.ylim(-0.5,9.25)
plt.xlim(0.3,.8)
#plt.ylim(2e-7,5e-4)

plt.xlabel("Pass Ratio",fontsize=26)
plt.ylabel("Cuts",fontsize=26)
plt.tick_params('both', length=10, width=2, which='major')
plt.tick_params('both', length=5, width=1, which='minor')
plt.xticks(fontsize=24)
plt.legend(loc='lower right',fontsize=20,shadow=True, fancybox=True,ncol=1)

plt.tight_layout()
#plt.savefig('/Users/austinmcdonald/Desktop/CutsNewVsOldS.pdf')
plt.show()

# %%
cd /Users/austinmcdonald/Desktop/Nexus-100kg
# Out:
# /Users/austinmcdonald/Desktop/Nexus-100kg

# %%
import glob

# %%
glob.glob('*.txt')
# Out:
# ['Algo-paramaters.txt',
#  'bb0nu-E.txt',
#  'bb0nublob.txt',
#  'Bi214-E.txt',
#  'Biblob.txt',
#  'Tl208-E.txt',
#  'Tlblob.txt',
#  'Vox.txt']

# %%
bbBlob = np.genfromtxt('bb0nublob.txt', delimiter=',')
BiBlob = np.genfromtxt('Biblob.txt', delimiter=',')
TlBlob = np.genfromtxt('Tlblob.txt', delimiter=',')

# %%
bbBlob[:,0]
# Out:
# array([ 0.        ,  0.11111111,  0.22222222,  0.33333333,  0.44444444,
#         0.55555556,  0.66666667,  0.77777778,  0.88888889,  1.        ])

# %%
BiBlob[:,1][4]
# Out:
# 6.0

# %%
fig, ax = plt.subplots(figsize=(7,7))
plt.scatter(bbBlob[:,0],bbBlob[:,1],color='b')
plt.axhline(3820)
plt.axvline(.45)
#plt.scatter(BiBlob[:,0],BiBlob[:,1]/BiBlob[:,1][0],color='g')
#plt.scatter(TlBlob[:,0],TlBlob[:,1]/TlBlob[:,1][0],color='r')
plt.plot()
# Out:
# []

# %%
fig, ax = plt.subplots(figsize=(7,7))
#plt.scatter(bbBlob[:,0],bbBlob[:,1],color='b')
plt.axhline(150)
#plt.scatter(BiBlob[:,0],BiBlob[:,1]/BiBlob[:,1][0],color='g')
plt.scatter(TlBlob[:,0],TlBlob[:,1],color='r')
plt.plot()
# Out:
# []

# %%
fig, ax = plt.subplots(figsize=(7,7))
plt.scatter(bbBlob[:,0],bbBlob[:,1]/bbBlob[:,1][0],color='b')
plt.scatter(BiBlob[:,0],BiBlob[:,1]/BiBlob[:,1][0],color='g')
plt.scatter(TlBlob[:,0],TlBlob[:,1]/TlBlob[:,1][0],color='r')
plt.plot()
# Out:
# []

# %%
fig, ax = plt.subplots(figsize=(7,7))
S = bbBlob[:,1]/bbBlob[:,1][0]
Bbi = BiBlob[:,1]/BiBlob[:,1][0]
Btl = TlBlob[:,1]/TlBlob[:,1][0]
plt.scatter(bbBlob[:,0],S/Bbi,color='b')
plt.scatter(BiBlob[:,0],S/Btl,color='g')
#plt.scatter(TlBlob[:,0],TlBlob[:,1]/TlBlob[:,1][0],color='r')
plt.plot()
# Out:
# //anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:5: RuntimeWarning: divide by zero encountered in true_divide
# []

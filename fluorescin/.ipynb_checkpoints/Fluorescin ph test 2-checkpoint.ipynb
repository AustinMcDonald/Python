# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter

# %matplotlib inline

# %%
cd /Users/austinmcdonald/Desktop/Plots/Fluorescin
# Out:
# /Users/austinmcdonald/Desktop/Plots/Fluorescin

# %%
#set path to the files location

path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/LED-488-22ms.csv' # this is the path
#Nled=len(os.listdir(path))                            # this is the number of files
#filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
#for x in range(1,Nled):
analysisled = np.genfromtxt(path,delimiter=",",skip_header=33,skip_footer=1)
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
#for y in range(0,x):
wavelength1 = (analysisled[:,0])
intensity = (analysisled[:,1])

    
#Meanwavelength = np.mean(wavelength,axis = 0)          # Finds the mean of the xvalues

#Meanintensity = np.mean(intensity,axis = 0)            # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr = Meanintensity + SDintensity                    # Adds the SD to the mean 
#dnerr = Meanintensity - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,intensity)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


plt.suptitle('LED Spectrum',size= 18)
plt.xlabel('Wavelength', fontsize=18)
plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    2f-0-1000 23 seconds PH7
#     
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-0-1000/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity0 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)             # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity1 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity1 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity0)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    2f-250-750 23 seconds  PH7
#
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-250-750/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity250 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)               # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity2 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity2 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity250)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    2f-500-500 23 seconds  PH7
#
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-500-500/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity500 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)               # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
uperr500 = Meanintensity500 + SDintensity                    # Adds the SD to the mean 
dnerr500 = Meanintensity500 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity500)
plt.plot(wavelength1,uperr500)
plt.plot(wavelength1,dnerr500)

plt.xlim([495,650])
#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    2f-750-250 PH6.5
#
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-750-250/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity750 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)               # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity4 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity4 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity750)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    2f-1000-0
#  PH ~4
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-1000-0/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity1000 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)               # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity4 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity4 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity1000)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    2f-800-200
#  PH ~6.5
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-800-200/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity800 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)               # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity4 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity4 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity800)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    2f-900-100
#  PH ~6
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-900-100/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity900 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)               # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity4 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity4 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity900)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    2f-950-50
#  PH ~5
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-950-50/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity950 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)               # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity4 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity4 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity950)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    2f-975-25
#  PH ~4
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-975-25/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity975 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)               # Finds the mean of the yvalues

SDintensity = np.std(intensity,axis = 0)               # Finds the SD of the yvalues
#uperr1 = Meanintensity4 + SDintensity                    # Adds the SD to the mean 
#dnerr1 = Meanintensity4 - SDintensity                    # Subtracts the SD from the mean

#plt.figure(figsize=(6,6))
plt.plot(wavelength1,Meanintensity975)
#plt.plot(Meanwavelength,uperr)
#plt.plot(Meanwavelength,dnerr)


#plt.suptitle('LED Spectrum',size= 18)
#plt.xlabel('Wavelength', fontsize=18)
#plt.ylabel('Intensity', fontsize=18)
plt.show()

# %%
#set path to the files location

#
#
#    2f-850-150
#  PH ~6
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-850-150/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity850 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)               # Finds the mean of the yvalues

plt.plot(wavelength1,Meanintensity850)
plt.show()

# %%
#set path to the files location

#
#
#    2f-625-375
#  PH ~6
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-625-375/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity625 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)               # Finds the mean of the yvalues

# %%
#set path to the files location

#
#
#    2f-375-625
#  PH ~6
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-375-625/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity375 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)               # Finds the mean of the yvalues

# %%
#set path to the files location

#
#
#    2f-100-900
#  PH ~6
#
path = '/Users/austinmcdonald/Desktop/data/LED Data/fluorescin/fluorescin buffer test 2/2F-100-900/' # this is the path
Nled=len(os.listdir(path))                            # this is the number of files
filenameled=list(os.listdir(path))                    # this puts the files into a list

# defining empty arrays 
analysisled = []
wavelength = []
intensity = []
# Importing all of the files and saving them to one array
for x in range(1,Nled):
    analysisled.append(pd.read_excel(path + filenameled[x],delimiter=",",header=None,skiprows=1,skip_footer=1))
    
# This picks out all of the xvals and yvals from the prevous array 
#... note it goes from 0 to x because mac puts an extra file in 
for y in range(0,x):
    wavelength.append(analysisled[y][0])
    intensity.append((analysisled[y][1]))
    
Meanintensity100 = savgol_filter(np.mean(intensity,axis = 0), 95, 3)               # Finds the mean of the yvalues

plt.plot(wavelength1,Meanintensity100)
plt.show()

# %%
plt.figure(figsize=(10,10))
#plt.plot(wavelength1,intensity*6)
plt.plot(wavelength1,Meanintensity0,label='0.0W,1.0B  PH~7')
plt.plot(wavelength1,Meanintensity250,label='0.25W,0.75B  PH~7')

plt.plot(wavelength1,Meanintensity500,label='0.5W,0.5B  PH~7')
#plt.plot(wavelength1,Meanintensity500*1.04, color='r', linestyle=':')
#plt.plot(wavelength1,Meanintensity500*0.96, color='r', linestyle=':')

plt.plot(wavelength1,Meanintensity750,label='0.75W,0.25B  PH~6.5')

plt.plot(wavelength1,Meanintensity800,label='0.8W,0.2B  PH~6.5')
#plt.plot(wavelength1,Meanintensity900/23*100,label='0.9W,0.1B  PH~6')
plt.plot(wavelength1,Meanintensity950,label='0.95W,0.05B  PH~5')

plt.plot(wavelength1,Meanintensity1000,label='1.0W,0.0B  PH~4')
#plt.plot(wavelength1,Meanintensity5/23*100,label='1.0W,0.0B  PH~4.5')


plt.axvline(520, color='g', linestyle='-')
plt.text(521,.1,'520nm',rotation=0,fontsize=15,color='g')
#plt.axvline(488, color='b', linestyle=':')
#plt.text(472,.8,'467nm',rotation=0,fontsize=15,color='b')

plt.legend(bbox_to_anchor=(.43, 1), loc=2, borderaxespad=0.,fontsize=22)


plt.suptitle('Fluorescein Buffer&PH Dependence',size= 32)
plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Relitive Intensity', fontsize=32)

plt.xlim([495,600])
plt.ylim([0,1])
#plt.savefig('Fluorescein Buffer&PH Dependence.pdf')
plt.show()

# %%
plt.figure(figsize=(10,10))
#plt.plot(wavelength1,intensity*6)
plt.plot(wavelength1,Meanintensity0,label='0.0W,1.0B  PH~7')
plt.plot(wavelength1,Meanintensity250,label='0.25W,0.75B  PH~7')
plt.plot(wavelength1,Meanintensity500,label='0.5W,0.5B  PH~7')
#plt.plot(wavelength1,Meanintensity750/21*100,label='0.75W,0.25B  PH~6.5')

#plt.plot(wavelength1,Meanintensity800/23*100,label='0.8W,0.2B  PH~6.5')
#plt.plot(wavelength1,Meanintensity900/23*100,label='0.9W,0.1B  PH~6')
#plt.plot(wavelength1,Meanintensity950/23*100,label='0.95W,0.05B  PH~5')

plt.plot(wavelength1,Meanintensity1000,label='1.0W,0.0B  PH~4')
#plt.plot(wavelength1,Meanintensity5/23*100,label='1.0W,0.0B  PH~4.5')


plt.axvline(520, color='g', linestyle='-')
plt.text(521,.1,'520nm',rotation=0,fontsize=15,color='g')
#plt.axvline(488, color='b', linestyle=':')
#plt.text(472,.8,'467nm',rotation=0,fontsize=15,color='b')

plt.legend(bbox_to_anchor=(.43, 1), loc=2, borderaxespad=0.,fontsize=22)


plt.suptitle('Fluorescein Buffer&PH Dependence',size= 32)
plt.xlabel('Wavelength (nm)', fontsize=32)
plt.ylabel('Relitive Intensity', fontsize=32)

plt.xlim([495,600])
plt.ylim([0,1])
#plt.savefig('Fluorescein Buffer&PH Dependence2.pdf')
plt.show()

# %%
Meanintensity500
# Out:
# array([ 0.04177663,  0.04116799,  0.04058027, ..., -0.0760746 ,
#        -0.08353237, -0.0912819 ])

# %%
buff = [0,25,50,100,150,200,250,375,500,625,750,900,1000]
BuffC = np.array(buff)
len(BuffC)
# Out:
# 13

# %%
ph = [4,4,5,6,6,6.5,6.5,7,7,7,7,7,7]
phC = np.array(ph)
len(phC)
# Out:
# 13

# %%
plt.scatter(BuffC,phC)
plt.ylim([3.5,7.3])
plt.show()

# %%
len(wavelength1)
# Out:
# 3648

# %%
wavelength1[1678]
wavelength1[1852]
# Out:
# 530.07159420000005

# %%
#area from 510-530
Awave = wavelength1[1678:1852]
# I is ammount of buffer
I0    = Meanintensity1000[1678:1852]
I25   = Meanintensity975[1678:1852]
I50   = Meanintensity950[1678:1852]
I100  = Meanintensity900[1678:1852]
I150  = Meanintensity850[1678:1852]
I200  = Meanintensity800[1678:1852]
I250  = Meanintensity750[1678:1852]
I375  = Meanintensity625[1678:1852]
I500  = Meanintensity500[1678:1852]
I625  = Meanintensity375[1678:1852]
I750  = Meanintensity250[1678:1852]
I900  = Meanintensity100[1678:1852]
I1000 = Meanintensity0[1678:1852]
#areas in ammount of buffer
A0    = np.trapz(I0,Awave)
A25   = np.trapz(I25,Awave)
A50   = np.trapz(I50,Awave)
A100  = np.trapz(I100,Awave)
A150  = np.trapz(I150,Awave)
A200  = np.trapz(I200,Awave)
A250  = np.trapz(I250,Awave)
A375  = np.trapz(I375,Awave)
A500  = np.trapz(I500,Awave)
A625  = np.trapz(I625,Awave)
A750  = np.trapz(I750,Awave)
A900  = np.trapz(I900,Awave)
A1000 = np.trapz(I1000,Awave)

barea = np.array([A0,A25,A50,A100,A150,A200,A250,A375,A500,A625,A750,A900,A1000])
plt.scatter(BuffC,barea)
plt.plot(BuffC,phC)
plt.show()

# %%
x = BuffC/1000
y1 = phC
y2 = barea
xerr = 0
y1err =.25
y2err = .04*barea


fig, ax1 = plt.subplots(figsize=(10,10))

ax2 = ax1.twinx()
ax1.plot(x,y1,color='r',linewidth=2)
ax1.scatter(x, y1,color='r',lw=3)
ax1.errorbar(x, y1, yerr=y1err,color='r')
ax2.scatter(x, y2,color='k',lw=3)
ax2.plot(x,y2,color='k',linewidth=2)
ax2.errorbar(x, y2, yerr=y2err,color='k')

ax1.set_xlabel(r'Buffer to Total Volume Ratio',fontsize=28)
ax1.set_ylabel('pH ', color='r',fontsize=28)
ax1.set_ylim([3.5,8.5])
ax2.set_ylim([5,17.9])

ax2.set_ylabel('Intensity in ROI (arb. units)', color='k',fontsize=28)

ax1.xaxis.set_tick_params(labelsize=26)
ax2.yaxis.set_tick_params(labelsize=26)
ax1.yaxis.set_tick_params(labelsize=26)
ax1.tick_params(axis='y',width=2,length=5)
ax2.tick_params(axis='y',width=2,length=5)
ax1.tick_params(axis='x',width=2,length=5)
ax1.tick_params(top="off")

#plt.suptitle('Fluorescein Buffer&PH Dependence',size= 22)
plt.tight_layout()
plt.xlim(-100/1000,1100/1000)
#plt.savefig('/Users/austinmcdonald/Desktop/Plots/paper8-16/Fluorescein_Buffer&PH_Dependence2.pdf')
plt.show()

# %%
#plt.plot(Awave,I0)
#plt.plot(Awave,I0)
plt.plot(Awave,I200)
plt.plot(Awave,I750)
plt.plot(Awave,I900)
plt.plot(Awave,I1000)
plt.show()

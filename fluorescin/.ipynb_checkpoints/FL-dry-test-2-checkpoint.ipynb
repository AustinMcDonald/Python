# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
from scipy import integrate

# %matplotlib inline

# %%
cd /Users/austinmcdonald/Desktop/data/fluorescin/8-26-16/dry2
# Out:
# /Users/austinmcdonald/Desktop/data/fluorescin/8-26-16/dry2

# %%
os.listdir()
# Out:
# ['clean1-1.csv',
#  'clean1-2.csv',
#  'clean1.csv',
#  'clean2.csv',
#  'dry1.csv',
#  'dry2.csv']

# %%
dry = pd.read_csv('dry1.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
clean = pd.read_csv('clean1-1.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')

# %%
dry['dif'] = dry['sig'].diff().abs()
dry['BS'] = dry['sig']-clean['sig']
dryf = dry[dry['dif']<.05]

# %%
plt.figure(figsize=(8,8))
plt.plot(dryf['wave'],dryf['sig'])

# %%
plt.figure(figsize=(8,8))
plt.plot(dry['wave'],dry['sig'])
plt.plot(clean['wave'],clean['sig'])

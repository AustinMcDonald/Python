# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import os
import glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
from scipy import integrate

# %matplotlib inline

# %%
path90 = '/Users/austinmcdonald/Desktop/data/fluorescin/8-24-16/TIR90mu'
path50 = '/Users/austinmcdonald/Desktop/data/fluorescin/8-24-16/TIR50mu'
path10 = '/Users/austinmcdonald/Desktop/data/fluorescin/8-24-16/TIR10mu'
path0  = '/Users/austinmcdonald/Desktop/data/fluorescin/8-24-16/water'

# %%
os.listdir(path0)
# Out:
# ['.DS_Store', 'CCD-noise.csv', 'w-1.csv', 'w-2.csv', 'w-3.csv', 'w-4.csv']

# %%
back90 = pd.read_csv(path90+'/CCD-noise.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
back50 = pd.read_csv(path50+'/CCD-noise.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
back10 = pd.read_csv(path10+'/CCD-noise.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
back0 = pd.read_csv(path0+'/CCD-noise.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')

dat90 = pd.read_csv(path90+'/tir90-1.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
dat50 = pd.read_csv(path50+'/tir50-1.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
dat10 = pd.read_csv(path10+'/tir10-1.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
datww = pd.read_csv(path0+'/w-1.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')

dat91 = pd.read_csv(path90+'/tir90-2.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
dat92 = pd.read_csv(path90+'/tir90-3.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
dat93 = pd.read_csv(path90+'/tir90-4.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')

dat51 = pd.read_csv(path50+'/tir50-2.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
dat52 = pd.read_csv(path50+'/tir50-3.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
dat53 = pd.read_csv(path50+'/tir50-4.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')

dat11 = pd.read_csv(path10+'/tir10-2.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
dat12 = pd.read_csv(path10+'/tir10-3.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
dat13 = pd.read_csv(path10+'/tir10-4.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')

datww1 = pd.read_csv(path0+'/w-2.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
datww2 = pd.read_csv(path0+'/w-3.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')
datww3 = pd.read_csv(path0+'/w-4.csv',delimiter=",",names = ['wave','sig'],skiprows=33,skipfooter=1,engine='python')

# %%
dat90['bs2']=((dat90['sig']-back90['sig'])+(dat91['sig']-back90['sig'])+(dat92['sig']-back90['sig'])+(dat93['sig']-back90['sig']))/4
dat50['bs2']=((dat50['sig']-back50['sig'])+(dat51['sig']-back50['sig'])+(dat52['sig']-back50['sig'])+(dat53['sig']-back50['sig']))/4
dat10['bs2']=((dat10['sig']-back10['sig'])+(dat11['sig']-back10['sig'])+(dat12['sig']-back10['sig'])+(dat13['sig']-back10['sig']))/4
datww['bs2']=((datww['sig']-back0['sig'])+(datww1['sig']-back0['sig'])+(datww2['sig']-back0['sig'])+(datww3['sig']-back0['sig']))/4

# %%
dat90 = dat90[dat90['sig']<.9]
dat90['bs'] = dat90['sig']-back90['sig']
dat90['dif'] = dat90['sig'].diff().abs()
dat90f = dat90[dat90['dif']<.1]

dat50 = dat50[dat50['sig']<.8]
dat50['bs'] = dat50['sig']-back50['sig']
dat50['dif'] = dat50['sig'].diff().abs()
dat50f = dat50[dat50['dif']<.07]

dat10 = dat10[dat10['sig']<.6]
dat10['bs'] = dat10['sig']-back10['sig']
dat10['dif'] = dat10['sig'].diff().abs()
dat10f = dat10[dat10['dif']<.07]

datww['bs'] = datww['sig']-back0['sig']
datww['dif'] = datww['sig'].diff().abs()
datwwf = datww[datww['dif']<.1]

# %%
savgol_filter(bas, amt, orde)

# %%
plt.figure(figsize=(10,10))
nor = max(dat90f['bs2'])
plt.plot(dat90f['wave'],dat90f['bs2']/nor,linewidth=2,color=cm.GnBu(2/5),label=r'$100 \mu M$'+' Fluorescein')
plt.plot(dat50f['wave'],dat50f['bs2']/nor,linewidth=2,color=cm.GnBu(3/5),label=r'$50 \mu M$'+' Fluorescein')
plt.plot(dat10f['wave'],dat10f['bs2']/nor,linewidth=2,color=cm.GnBu(4/5),label=r'$10 \mu M$'+' Fluorescein')
plt.plot(datww['wave'],datww['bs2']/nor,  linewidth=2,color=cm.GnBu(5/5),label=r'$0 \mu M$'+' Fluorescein')

plt.legend(bbox_to_anchor=(1,1), loc=1, borderaxespad=0.,fontsize=22,shadow=True, fancybox=True)
plt.xlabel(r'Wavelength ($nm$)', fontsize=28)
plt.ylabel('Intensity (arb. units)', fontsize=28)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xticks([450,475,500,525,550,575,600,625],ha='left')
plt.tick_params(top="off",right='off')
plt.tick_params(axis='x', direction='out',width=2,length=5)
plt.tick_params(axis='y',width=2,length=5)

plt.tight_layout()
plt.xlim(450,650)
plt.ylim(0,1.02)
#plt.savefig('/Users/austinmcdonald/Desktop/Plots/paper8-16/Ar_FL_tir2.pdf')
plt.show()

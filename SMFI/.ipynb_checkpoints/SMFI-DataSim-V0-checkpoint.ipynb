# %%
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from matplotlib.colors import LogNorm
import matplotlib.colors as mcolors

# %matplotlib inline

# %%
def Gauss(x, a, x0, sigma):
    return a * np.exp(-(x - x0)**2 / (2 * sigma**2))
def find_nearest(array,value):
    idx = (np.abs(array-value)).argmin()
    return array[idx]
def find_fit_vals(dataX,dataY):
    maxx = max(dataY)
    sig_val = maxx*0.5
    MeanLoc = np.where(dataY==max(dataY))[0][0]
    Mean = dataX[MeanLoc]
    L = dataY[0:MeanLoc]
    R = dataY[MeanLoc:len(dataY)]
    LP =find_nearest(L,sig_val)
    RP =find_nearest(R,sig_val)
    whereL = np.where(L==LP)[0][0]
    whereR = np.where(R==RP)[0][0]
    Lpoint = dataX[whereL]
    Rpoint = dataX[MeanLoc+whereR]
    sigma_point = (Rpoint-Lpoint)/2   
    return (Mean,sigma_point)

# %%
Num=1000
x4 = np.random.rand(Num)
y4 = np.random.rand(Num)

bins = 10
plt.figure(figsize=(8,8))
plt.title(r'Testing the random histogram',fontsize=20)

xedges, yedges = np.linspace(0, 1, bins), np.linspace(0, 1, bins)
#plt.hist2d(x4, y4, bins=(xedges, yedges), norm=LogNorm())
plt.hist2d(x4, y4, bins=(xedges, yedges))
plt.colorbar()
plt.xlim(0,1)
plt.ylim(0,1)
#plt.axhline(75,linewidth=2,linestyle='--',color='r')
#plt.axvline(-0.5,linewidth=2,linestyle='--',color='r')
plt.grid(True)
#plt.savefig('/Users/austinmcdonald/Desktop/fitting/'+'chiBadata-cut')
plt.show()

# %%
def gaussian2D(height, x, y, center_x, center_y, width_x, width_y):
    """Returns a gaussian function with the given parameters"""
    width_x = float(width_x)
    width_y = float(width_y)
    return height*np.exp(-(((center_x-x)/width_x)**2+((center_y-y)/width_y)**2)/2)

# %%
#calculating the sigma (x/y width) for a 530nm emission with a 1.4NA objective
#this is the defraction limit of the emission light
(530/(2*1.4))/160
# Out:
# 1.1830357142857144

# %%
#Testing a full 512x512 ccd with a gaussian emission
#with random noise


Num=10000000
x4 = np.random.rand(Num)*512
y4 = np.random.rand(Num)*512
ran = np.random.rand(Num)*1e-1
R   = 0.8 + 0.4*np.random.rand(1)
WW = gaussian2D(R,x4,y4,200,200,1.18,1.18)/5
R   = 0.8 + 0.4*np.random.rand(1)
WWW = gaussian2D(R,x4,y4,195,210,1.18,1.18)/5
WW = WW+ran+WWW
#WW =ran

bins = 513
plt.figure(figsize=(8,8))
plt.title(r'Testing the random gaussian',fontsize=20)

xedges, yedges = np.linspace(0, 513, bins), np.linspace(0, 513, bins)
#plt.hist2d(x4, y4, bins=(xedges, yedges), norm=LogNorm())
plt.hist2d(x4, y4, bins=(xedges, yedges),weights=WW,cmap='afmhot')
plt.colorbar()
plt.xlim(0,512)
plt.ylim(0,512)
#plt.xlim(190,215)
#plt.ylim(190,215)
plt.grid(True)
#plt.savefig('/Users/austinmcdonald/Desktop/fitting/'+'chiBadata-cut')
plt.show()

# %%
np.random.randint(0,512,size=1)[0]
# Out:
# 454

# %%
#function to generate random gaussian points in the 512x512
#arguments are number of points to generate and number of gaussians to fill
def RAND_POINT(NUM, Nxy ):
    x4 = np.random.rand(Num)*512
    y4 = np.random.rand(Num)*512
    ran = np.random.rand(Num)*1e-1
    Weight = ran
    for qw in range(0,Nxy):
        Xpoint = np.random.randint(0,512,size=1)[0]
        Ypoint = np.random.randint(0,512,size=1)[0]
        R   = 0.8 + 0.4*np.random.rand(1)
        WW = gaussian2D(R,x4,y4,Xpoint,Ypoint,1.18,1.18)/5
        Weight+=WW
    return x4, y4, Weight

# %%
X,Y,W = RAND_POINT(10000000,10)

# %%
# This plots it and looks pretty good 
#as in it looks kinda like the data in a perfect condition
bins = 513
plt.figure(figsize=(8,8))
plt.title(r'Testing the random gaussian',fontsize=20)

xedges, yedges = np.linspace(0, 513, bins), np.linspace(0, 513, bins)
#plt.hist2d(x4, y4, bins=(xedges, yedges), norm=LogNorm())
plt.hist2d(X, Y, bins=(xedges, yedges),weights=W,cmap='afmhot')
plt.colorbar()
plt.xlim(0,512)
plt.ylim(0,512)
#plt.xlim(190,215)
#plt.ylim(190,215)
plt.grid(True)
#plt.savefig('/Users/austinmcdonald/Desktop/fitting/'+'chiBadata-cut')
plt.show()

# %%
#Moving the function to generate a smaller image 100x100
def RAND_POINT(NUM, Nxy ):
    x4 = np.random.rand(Num)*100
    y4 = np.random.rand(Num)*100
    ran = np.random.rand(Num)#*1e-1
    Weight = ran
    for qw in range(0,Nxy):
        Xpoint = np.random.randint(0,100,size=1)[0]
        Ypoint = np.random.randint(0,100,size=1)[0]
        R   = 0.8 + 0.4*np.random.rand(1)
        WW = gaussian2D(2*R,x4,y4,Xpoint,Ypoint,1.18,1.18)
        Weight+=WW
    return x4, y4, Weight

# %%
X,Y,W = RAND_POINT(100000,10)

# %%
#Moving the function to generate a smaller image

#looks like it worked
bins = 513
plt.figure(figsize=(8,8))
plt.title(r'Testing the random gaussian',fontsize=20)

xedges, yedges = np.linspace(0, 513, bins), np.linspace(0, 513, bins)
#plt.hist2d(x4, y4, bins=(xedges, yedges), norm=LogNorm())
plt.hist2d(X, Y, bins=(xedges, yedges),weights=W,cmap='afmhot')
plt.colorbar()
plt.xlim(0,512)
plt.ylim(0,512)
plt.grid(True)
plt.show()

plt.hist2d(X, Y, bins=(xedges, yedges),weights=W,cmap='afmhot')
plt.colorbar()
plt.xlim(0,100)
plt.ylim(0,100)
plt.grid(True)
#plt.savefig('/Users/austinmcdonald/Desktop/fitting/'+'chiBadata-cut')
plt.show()

# %%
np.sqrt(3.14*1.18*2)

# %%
# Added Figure Of Merit (FOM) to judge the signal to background 
# this is how we can generate data with the Fmax/Fmin data from the spectromemter
def RAND_POINT(NUM, Nxy ,Back_rejection):
    x4 = np.random.rand(Num)*60
    y4 = np.random.rand(Num)*60
    ran = np.random.rand(Num)*Back_rejection
    Weight = ran
    for qw in range(0,Nxy):
        Xpoint = np.random.randint(20,40,size=1)[0]
        Ypoint = np.random.randint(20,40,size=1)[0]
        R   = 1#0.8 + 0.4*np.random.rand(1)
        WW = gaussian2D(R,x4,y4,Xpoint,Ypoint,1.38,1.38)
        Weight+=WW
    return x4, y4, Weight

def FOM(x,y,w):
    xedges, yedges = np.linspace(0, 513, bins), np.linspace(0, 513, bins)
    H,xx,yy = np.histogram2d(x, y, bins=(xedges, yedges),weights=w)
    back = 0
    counter = 0
    SIG = 0
    for q in range(0,len(xx)-1):
        for w in range(0,len(yy)-1): 
            MAX = H[q][w]
            if MAX>SIG:
                SIG = MAX
            if xx[q]<20 and yy[w]<20:
                back+=H[q][w]
                counter+=1
    BACK = back/counter
    return SIG/BACK

# %%
# shooting for a FOM of ~200ish
#got about 170 here to match franks molecule 
X,Y,W = RAND_POINT(100000,1,1e-2)

FOM(X,Y,W)
# Out:
# 172.33844864903173

# %%
bins = 513
plt.figure(figsize=(8,8))
plt.title(r'Testing the random gaussian',fontsize=20)

xedges, yedges = np.linspace(0, 513, bins), np.linspace(0, 513, bins)
#plt.hist2d(x4, y4, bins=(xedges, yedges), norm=LogNorm())
hist = plt.hist2d(X, Y, bins=(xedges, yedges),weights=W,cmap='afmhot')
plt.colorbar()
plt.xlim(0,512)
plt.ylim(0,512)
plt.grid(True)
plt.show()

plt.hist2d(X, Y, bins=(xedges, yedges),weights=W,cmap='afmhot')
plt.colorbar()
plt.xlim(0,60)
plt.ylim(0,60)
plt.grid(True)
#plt.savefig('/Users/austinmcdonald/Desktop/fitting/'+'chiBadata-cut')
plt.show()

# %%
# Adjusting the random point function to give random oise from various gausians 
##
# THIS IS NOT WORKING
#
def RAND_POINT(Num, Nxy ,Back_rejection):
    x4 = np.random.rand(Num)*60
    y4 = np.random.rand(Num)*60
    rr = []
    for er in range(0,Num):
        hold1 = np.random.rand(1)*60
        hold2 = np.random.rand(1)*60
        rr.append(gaussian2D(1,x4[er],y4[er],hold1,hold2,1.38,1.38)*Back_rejection)
    #ran = np.random.rand(Num)*Back_rejection
    Weight = rr#np.array(rr)
    for qw in range(0,Nxy):
        Xpoint = np.random.randint(20,40,size=1)[0]
        Ypoint = np.random.randint(20,40,size=1)[0]
        R   = 1#0.8 + 0.4*np.random.rand(1)
        WW = gaussian2D(R,x4,y4,Xpoint,Ypoint,1.38,1.38)
        Weight+=WW
    return x4, y4, Weight

def FOM(x,y,w):
    xedges, yedges = np.linspace(0, 513, bins), np.linspace(0, 513, bins)
    H,xx,yy = np.histogram2d(x, y, bins=(xedges, yedges),weights=w)
    back = 0
    counter = 0
    SIG = 0
    for q in range(0,len(xx)-1):
        for w in range(0,len(yy)-1): 
            MAX = H[q][w]
            if MAX>SIG:
                SIG = MAX
            if xx[q]<20 and yy[w]<20:
                back+=H[q][w]
                counter+=1
    BACK = back/counter
    return SIG/BACK

# %%
##
# THIS IS NOT WORKING
#
X,Y,W = RAND_POINT(1000,4,1e-2)
FOM(X,Y,W)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-36017ddaeae7> in <module>
#       1 X,Y,W = RAND_POINT(1000,4,1e-2)
# ----> 2 FOM(X,Y,W)
#
# <ipython-input-28-4ab7154a3b37> in FOM(x, y, w)
#      21 def FOM(x,y,w):
#      22     xedges, yedges = np.linspace(0, 513, bins), np.linspace(0, 513, bins)
# ---> 23     H,xx,yy = np.histogram2d(x, y, bins=(xedges, yedges),weights=w)
#      24     back = 0
#      25     counter = 0
#
# ~/miniconda/envs/IC-3.6-2018-11-14/lib/python3.6/site-packages/numpy/lib/twodim_base.py in histogram2d(x, y, bins, range, normed, weights, density)
#     659         xedges = yedges = asarray(bins)
#     660         bins = [xedges, yedges]
# --> 661     hist, edges = histogramdd([x, y], bins, range, normed, weights, density)
#     662     return hist, edges[0], edges[1]
#     663
#
# ...

# %%
##
# THIS IS NOT WORKING
#
bins = 513
plt.figure(figsize=(8,8))
#plt.title(r'Testing the random gaussian',fontsize=20_

plt.hist2d(X, Y, bins=(xedges, yedges),weights=W,cmap='afmhot')
plt.colorbar()
plt.xlim(0,60)
plt.ylim(0,60)
plt.grid(True)
#plt.savefig('/Users/austinmcdonald/Desktop/fitting/'+'chiBadata-cut')
plt.show()

# %%
# ordering the random poins with some spacing
#
# This should simulate the expected ALICE data with spacking defined by Space
#Starting with a defined x point of 20 and adding the spacing 
def RAND_POINT(NUM, Nxy ,Back_rejection,space):
    x4 = np.random.rand(Num)*60
    y4 = np.random.rand(Num)*60
    ran = np.random.rand(Num)*Back_rejection
    Weight = ran
    for qw in range(0,Nxy):
        Xpoint = 20+space[qw]
        Ypoint = 20+space[qw]
        R   = 1#0.8 + 0.4*np.random.rand(1)
        WW = gaussian2D(R,x4,y4,Xpoint,Ypoint,1.38,1.38)
        Weight+=WW
    return x4, y4, Weight

def FOM(x,y,w):
    xedges, yedges = np.linspace(0, 513, bins), np.linspace(0, 513, bins)
    H,xx,yy = np.histogram2d(x, y, bins=(xedges, yedges),weights=w)
    back = 0
    counter = 0
    SIG = 0
    for q in range(0,len(xx)-1):
        for w in range(0,len(yy)-1): 
            MAX = H[q][w]
            if MAX>SIG:
                SIG = MAX
            if xx[q]<20 and yy[w]<20:
                back+=H[q][w]
                counter+=1
    BACK = back/counter
    return SIG/BACK

# %%
#
# If i did this right the space shuold be 1 pixel 
#
# Here I am dividing by 160 because that is what my objective sees on the sample
# this should put it in nm
Space = np.arange(0,2000)/160

# %%
Space
# Out:
# array([0.000000e+00, 6.250000e-03, 1.250000e-02, ..., 1.248125e+01,
#        1.248750e+01, 1.249375e+01])

# %%
# Generating 100 points with 1nm spacing
X,Y,W = RAND_POINT(1000,100,1e-2,Space)

# %%
# HAHA well should of expected 100 points at 1nm would be just a blob

bins = 513
plt.figure(figsize=(8,8))
plt.title(r'Testing the random gaussian',fontsize=20)

xedges, yedges = np.linspace(0, 513, bins), np.linspace(0, 513, bins)

plt.hist2d(X, Y, bins=(xedges, yedges),weights=W,cmap='afmhot')
plt.colorbar()
plt.xlim(0,60)
plt.ylim(0,60)
plt.grid(True)
#plt.savefig('/Users/austinmcdonald/Desktop/fitting/'+'chiBadata-cut')
plt.show()

# %%
# Generating 1000 points with 1nm spacing
X,Y,W = RAND_POINT(1000,1000,1e-2,Space)

# %%
# Increasing by an order of mangaude gives a stubby line

bins = 513
plt.figure(figsize=(8,8))
plt.title(r'Testing the random gaussian',fontsize=20)

xedges, yedges = np.linspace(0, 513, bins), np.linspace(0, 513, bins)

plt.hist2d(X, Y, bins=(xedges, yedges),weights=W,cmap='afmhot')
plt.colorbar()
plt.xlim(0,60)
plt.ylim(0,60)
plt.grid(True)
#plt.savefig('/Users/austinmcdonald/Desktop/fitting/'+'chiBadata-cut')
plt.show()
